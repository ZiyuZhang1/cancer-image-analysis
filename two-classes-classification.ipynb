# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import glob
import os
from tensorflow.keras.callbacks import TensorBoard
import time
import pickle
import matplotlib.pyplot as plt
from sklearn import metrics

# %% [markdown]
# # set parameters

# %%
batch_size = 32
epoch = 150
img_height = 300
img_width = 300
root = '/A_LUAD/project/final_project'
name = '2-class-original{}'.format(int(time.time()))
tensorboard = TensorBoard(log_dir='/A_LUAD/project/final_project/logs/{}'.format(name))

# %% [markdown]
# # load data

# %%
train_dir = '/A_LUAD/project/final_project/data/temp/two_train'
val_dir = '/A_LUAD/project/final_project/data/temp/two_val'

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_dir,
  image_size=(img_height, img_width),
  batch_size=batch_size)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  val_dir,
  image_size=(img_height, img_width),
  batch_size=batch_size)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 3075 files belonging to 2 classes.
# Found 652 files belonging to 2 classes.

# %% [markdown]
# # build model

# %%
class ConfusionMatrixMetric(tf.keras.metrics.Metric):
    """
    A custom Keras metric to compute the running average of the confusion matrix
    """
    def __init__(self, num_classes, **kwargs):
        super(ConfusionMatrixMetric,self).__init__(name='confusion_matrix_metric',**kwargs) # handles base args (e.g., dtype)
        self.num_classes=num_classes
        self.total_cm = self.add_weight("total", shape=(num_classes,num_classes), initializer="zeros")
        
    def reset_state(self):
        for s in self.variables:
            s.assign(tf.zeros(shape=s.shape))
            
    def update_state(self, y_true, y_pred,sample_weight=None):
        self.total_cm.assign_add(self.confusion_matrix(y_true,y_pred))
        return self.total_cm
        
    def result(self):
        return self.process_confusion_matrix()
    
    def confusion_matrix(self,y_true, y_pred):
        """
        Make a confusion matrix
        """
        y_pred=tf.argmax(y_pred,1)
        cm=tf.math.confusion_matrix(y_true,y_pred,dtype=tf.float32,num_classes=self.num_classes)
        return cm
    
    def process_confusion_matrix(self):
        "returns precision, recall and f1 along with overall accuracy"
        cm=self.total_cm
        diag_part=tf.linalg.diag_part(cm)
        precision=diag_part/(tf.reduce_sum(cm,0)+tf.constant(1e-15))
        recall=diag_part/(tf.reduce_sum(cm,1)+tf.constant(1e-15))
        f1=2*precision*recall/(precision+recall+tf.constant(1e-15))
        return precision,recall,f1
    
    def fill_output(self,output):
        results=self.result()
        for i in range(self.num_classes):
            output['precision_{}'.format(i)]=results[0][i]
            output['recall_{}'.format(i)]=results[1][i]
            output['F1_{}'.format(i)]=results[2][i]
    # def get_config(self):
    #     config = super(ConfusionMatrixMetric, self).get_config()
    #     config.update({"num_classes": self.num_classes,"total_cm": self.total_cm})
    #     return config
    
class MySequential(keras.Sequential):
    
    def train_step(self, data):
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.

        x, y = data

        with tf.GradientTape() as tape:
            y_pred = self(x, training=True)  # Forward pass
            # Compute the loss value.
            # The loss function is configured in `compile()`.
            loss = self.compiled_loss(
                y,
                y_pred,
                regularization_losses=self.losses,
            )

        # Compute gradients
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.compiled_metrics.update_state(y, y_pred)
        output={m.name: m.result() for m in self.metrics[:-1]}
        if 'confusion_matrix_metric' in self.metrics_names:
            self.metrics[-1].fill_output(output)
        return output
        
        
    def test_step(self, data):
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.

        x, y = data

        y_pred = self(x, training=False)  # Forward pass
        # Compute the loss value.
        # The loss function is configured in `compile()`.
        loss = self.compiled_loss(
            y,
            y_pred,
            regularization_losses=self.losses,
        )

        self.compiled_metrics.update_state(y, y_pred)
        output={m.name: m.result() for m in self.metrics[:-1]}
        if 'confusion_matrix_metric' in self.metrics_names:
            self.metrics[-1].fill_output(output)    
        return output

# %% [markdown]
# ## with data augmentatiom

# %%
data_augmentation = keras.Sequential(
  [
    keras.layers.experimental.preprocessing.RandomFlip("horizontal",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    keras.layers.experimental.preprocessing.RandomRotation(0.1),
    keras.layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

####### model
num_classes = 2
# Dropout
model = MySequential([
  data_augmentation,
  keras.layers.experimental.preprocessing.Rescaling(1./300),
  keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Dropout(0.2),
  keras.layers.GlobalAveragePooling2D(),
  keras.layers.Dense(64, activation='relu'),
  keras.layers.Dense(64, activation='relu'),
  keras.layers.Dense(num_classes)
])
loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer=keras.optimizers.Adam()
model.compile(loss=loss,optimizer=optimizer,metrics=['accuracy',ConfusionMatrixMetric(2)])

# %% [markdown]
# # train

# %%
# es=keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=100)
history=model.fit(train_ds,validation_data=val_ds,epochs=epoch, verbose=1, callbacks=[tensorboard])
# Out:
# Epoch 1/150
# 97/97 [==============================] - 13s 97ms/step - loss: 0.6622 - accuracy: 0.6143 - precision_0: 0.6061 - recall_0: 0.9449 - F1_0: 0.7371 - precision_1: 0.3438 - recall_1: 0.0490 - F1_1: 0.0639 - val_loss: 0.5466 - val_accuracy: 0.8466 - val_precision_0: 0.8466 - val_recall_0: 1.0000 - val_F1_0: 0.9169 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_F1_1: 0.0000e+00
# Epoch 2/150
# 97/97 [==============================] - 9s 89ms/step - loss: 0.6412 - accuracy: 0.6485 - precision_0: 0.6281 - recall_0: 0.9936 - F1_0: 0.7695 - precision_1: 0.7946 - recall_1: 0.0523 - F1_1: 0.0949 - val_loss: 0.6025 - val_accuracy: 0.8083 - val_precision_0: 0.8726 - val_recall_0: 0.9058 - val_F1_0: 0.8889 - val_precision_1: 0.3418 - val_recall_1: 0.2700 - val_F1_1: 0.3017
# Epoch 3/150
# 97/97 [==============================] - 9s 89ms/step - loss: 0.6138 - accuracy: 0.6722 - precision_0: 0.6516 - recall_0: 0.9657 - F1_0: 0.7781 - precision_1: 0.7632 - recall_1: 0.1779 - F1_1: 0.2874 - val_loss: 0.6124 - val_accuracy: 0.7807 - val_precision_0: 0.8711 - val_recall_0: 0.8696 - val_F1_0: 0.8704 - val_precision_1: 0.2871 - val_recall_1: 0.2900 - val_F1_1: 0.2886
# Epoch 4/150
# 97/97 [==============================] - 9s 89ms/step - loss: 0.6073 - accuracy: 0.6706 - precision_0: 0.6658 - recall_0: 0.9460 - F1_0: 0.7814 - precision_1: 0.7094 - recall_1: 0.2101 - F1_1: 0.3208 - val_loss: 0.9174 - val_accuracy: 0.7270 - val_precision_0: 0.8912 - val_recall_0: 0.7717 - val_F1_0: 0.8272 - val_precision_1: 0.2759 - val_recall_1: 0.4800 - val_F1_1: 0.3504
# Epoch 5/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5956 - accuracy: 0.6767 - precision_0: 0.6598 - recall_0: 0.9542 - F1_0: 0.7801 - precision_1: 0.7601 - recall_1: 0.2145 - F1_1: 0.3334 - val_loss: 0.5708 - val_accuracy: 0.8083 - val_precision_0: 0.8637 - val_recall_0: 0.9185 - val_F1_0: 0.8903 - val_precision_1: 0.3077 - val_recall_1: 0.2000 - val_F1_1: 0.2424
# Epoch 6/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5786 - accuracy: 0.6813 - precision_0: 0.6651 - recall_0: 0.9715 - F1_0: 0.7896 - precision_1: 0.8111 - recall_1: 0.2020 - F1_1: 0.3222 - val_loss: 0.5422 - val_accuracy: 0.8021 - val_precision_0: 0.8717 - val_recall_0: 0.8986 - val_F1_0: 0.8849 - val_precision_1: 0.3253 - val_recall_1: 0.2700 - val_F1_1: 0.2951
# Epoch 7/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.6065 - accuracy: 0.6774 - precision_0: 0.6449 - recall_0: 0.9729 - F1_0: 0.7753 - precision_1: 0.8138 - recall_1: 0.1792 - F1_1: 0.2927 - val_loss: 0.5740 - val_accuracy: 0.8021 - val_precision_0: 0.8653 - val_recall_0: 0.9076 - val_F1_0: 0.8859 - val_precision_1: 0.3014 - val_recall_1: 0.2200 - val_F1_1: 0.2543
# Epoch 8/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5950 - accuracy: 0.6813 - precision_0: 0.6655 - recall_0: 0.9745 - F1_0: 0.7907 - precision_1: 0.8373 - recall_1: 0.2085 - F1_1: 0.3327 - val_loss: 0.5454 - val_accuracy: 0.8083 - val_precision_0: 0.8637 - val_recall_0: 0.9185 - val_F1_0: 0.8903 - val_precision_1: 0.3077 - val_recall_1: 0.2000 - val_F1_1: 0.2424
# Epoch 9/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5812 - accuracy: 0.6751 - precision_0: 0.6590 - recall_0: 0.9600 - F1_0: 0.7814 - precision_1: 0.7760 - recall_1: 0.2135 - F1_1: 0.3323 - val_loss: 0.6399 - val_accuracy: 0.7745 - val_precision_0: 0.8662 - val_recall_0: 0.8678 - val_F1_0: 0.8670 - val_precision_1: 0.2626 - val_recall_1: 0.2600 - val_F1_1: 0.2613
# Epoch 10/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5910 - accuracy: 0.6683 - precision_0: 0.6690 - recall_0: 0.8492 - F1_0: 0.7467 - precision_1: 0.6182 - recall_1: 0.3387 - F1_1: 0.4224 - val_loss: 0.5996 - val_accuracy: 0.7914 - val_precision_0: 0.8701 - val_recall_0: 0.8859 - val_F1_0: 0.8779 - val_precision_1: 0.3000 - val_recall_1: 0.2700 - val_F1_1: 0.2842
# Epoch 11/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5888 - accuracy: 0.6810 - precision_0: 0.6637 - recall_0: 0.9790 - F1_0: 0.7911 - precision_1: 0.8377 - recall_1: 0.1811 - F1_1: 0.2965 - val_loss: 0.6482 - val_accuracy: 0.7776 - val_precision_0: 0.8707 - val_recall_0: 0.8659 - val_F1_0: 0.8683 - val_precision_1: 0.2816 - val_recall_1: 0.2900 - val_F1_1: 0.2857
# Epoch 12/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5807 - accuracy: 0.6820 - precision_0: 0.6621 - recall_0: 0.9787 - F1_0: 0.7898 - precision_1: 0.8566 - recall_1: 0.2007 - F1_1: 0.3248 - val_loss: 0.7373 - val_accuracy: 0.7546 - val_precision_0: 0.8712 - val_recall_0: 0.8333 - val_F1_0: 0.8519 - val_precision_1: 0.2581 - val_recall_1: 0.3200 - val_F1_1: 0.2857
# Epoch 13/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5575 - accuracy: 0.6911 - precision_0: 0.6676 - recall_0: 0.9546 - F1_0: 0.7856 - precision_1: 0.7875 - recall_1: 0.2608 - F1_1: 0.3913 - val_loss: 0.6335 - val_accuracy: 0.7776 - val_precision_0: 0.8680 - val_recall_0: 0.8696 - val_F1_0: 0.8688 - val_precision_1: 0.2727 - val_recall_1: 0.2700 - val_F1_1: 0.2714
# Epoch 14/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5719 - accuracy: 0.6846 - precision_0: 0.6651 - recall_0: 0.9600 - F1_0: 0.7855 - precision_1: 0.7989 - recall_1: 0.2418 - F1_1: 0.3691 - val_loss: 0.6377 - val_accuracy: 0.7899 - val_precision_0: 0.8660 - val_recall_0: 0.8895 - val_F1_0: 0.8776 - val_precision_1: 0.2824 - val_recall_1: 0.2400 - val_F1_1: 0.2595
# Epoch 15/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5895 - accuracy: 0.6803 - precision_0: 0.6614 - recall_0: 0.9817 - F1_0: 0.7903 - precision_1: 0.8755 - recall_1: 0.1936 - F1_1: 0.3160 - val_loss: 0.7917 - val_accuracy: 0.7454 - val_precision_0: 0.8683 - val_recall_0: 0.8243 - val_F1_0: 0.8457 - val_precision_1: 0.2422 - val_recall_1: 0.3100 - val_F1_1: 0.2719
# Epoch 16/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5563 - accuracy: 0.6917 - precision_0: 0.6691 - recall_0: 0.9647 - F1_0: 0.7899 - precision_1: 0.8234 - recall_1: 0.2551 - F1_1: 0.3888 - val_loss: 0.7246 - val_accuracy: 0.7561 - val_precision_0: 0.8757 - val_recall_0: 0.8297 - val_F1_0: 0.8521 - val_precision_1: 0.2713 - val_recall_1: 0.3500 - val_F1_1: 0.3057
# Epoch 17/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5354 - accuracy: 0.6943 - precision_0: 0.6881 - recall_0: 0.9262 - F1_0: 0.7894 - precision_1: 0.7662 - recall_1: 0.3431 - F1_1: 0.4700 - val_loss: 0.5904 - val_accuracy: 0.7684 - val_precision_0: 0.8706 - val_recall_0: 0.8533 - val_F1_0: 0.8618 - val_precision_1: 0.2703 - val_recall_1: 0.3000 - val_F1_1: 0.2844
# Epoch 18/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5433 - accuracy: 0.6823 - precision_0: 0.6677 - recall_0: 0.9510 - F1_0: 0.7843 - precision_1: 0.7768 - recall_1: 0.2432 - F1_1: 0.3661 - val_loss: 0.6615 - val_accuracy: 0.7485 - val_precision_0: 0.8688 - val_recall_0: 0.8279 - val_F1_0: 0.8479 - val_precision_1: 0.2460 - val_recall_1: 0.3100 - val_F1_1: 0.2743
# Epoch 19/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5303 - accuracy: 0.6992 - precision_0: 0.6818 - recall_0: 0.9462 - F1_0: 0.7921 - precision_1: 0.7814 - recall_1: 0.2897 - F1_1: 0.4181 - val_loss: 0.8973 - val_accuracy: 0.7178 - val_precision_0: 0.8651 - val_recall_0: 0.7899 - val_F1_0: 0.8258 - val_precision_1: 0.2162 - val_recall_1: 0.3200 - val_F1_1: 0.2581
# Epoch 20/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5249 - accuracy: 0.7008 - precision_0: 0.6988 - recall_0: 0.9019 - F1_0: 0.7870 - precision_1: 0.7328 - recall_1: 0.3998 - F1_1: 0.5139 - val_loss: 0.7657 - val_accuracy: 0.4739 - val_precision_0: 0.8215 - val_recall_0: 0.4837 - val_F1_0: 0.6089 - val_precision_1: 0.1284 - val_recall_1: 0.4200 - val_F1_1: 0.1967
# Epoch 21/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5542 - accuracy: 0.6959 - precision_0: 0.7252 - recall_0: 0.8309 - F1_0: 0.7729 - precision_1: 0.6329 - recall_1: 0.4745 - F1_1: 0.5369 - val_loss: 0.8681 - val_accuracy: 0.7163 - val_precision_0: 0.8663 - val_recall_0: 0.7862 - val_F1_0: 0.8243 - val_precision_1: 0.2185 - val_recall_1: 0.3300 - val_F1_1: 0.2629
# Epoch 22/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5562 - accuracy: 0.6998 - precision_0: 0.6766 - recall_0: 0.9612 - F1_0: 0.7940 - precision_1: 0.8078 - recall_1: 0.2520 - F1_1: 0.3813 - val_loss: 0.7873 - val_accuracy: 0.5951 - val_precision_0: 0.8830 - val_recall_0: 0.6014 - val_F1_0: 0.7155 - val_precision_1: 0.2029 - val_recall_1: 0.5600 - val_F1_1: 0.2979
# Epoch 23/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5220 - accuracy: 0.7193 - precision_0: 0.6975 - recall_0: 0.9062 - F1_0: 0.7876 - precision_1: 0.6939 - recall_1: 0.3430 - F1_1: 0.4548 - val_loss: 0.9857 - val_accuracy: 0.5675 - val_precision_0: 0.8610 - val_recall_0: 0.5833 - val_F1_0: 0.6955 - val_precision_1: 0.1727 - val_recall_1: 0.4800 - val_F1_1: 0.2540
# Epoch 24/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5379 - accuracy: 0.7011 - precision_0: 0.7109 - recall_0: 0.9265 - F1_0: 0.8040 - precision_1: 0.7369 - recall_1: 0.3476 - F1_1: 0.4694 - val_loss: 0.9518 - val_accuracy: 0.6012 - val_precision_0: 0.8763 - val_recall_0: 0.6159 - val_F1_0: 0.7234 - val_precision_1: 0.1970 - val_recall_1: 0.5200 - val_F1_1: 0.2857
# Epoch 25/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.5042 - accuracy: 0.7356 - precision_0: 0.7391 - recall_0: 0.9062 - F1_0: 0.8139 - precision_1: 0.7616 - recall_1: 0.4799 - F1_1: 0.5875 - val_loss: 1.0858 - val_accuracy: 0.4310 - val_precision_0: 0.8364 - val_recall_0: 0.4076 - val_F1_0: 0.5481 - val_precision_1: 0.1462 - val_recall_1: 0.5600 - val_F1_1: 0.2319
# Epoch 26/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.4951 - accuracy: 0.7587 - precision_0: 0.7657 - recall_0: 0.8741 - F1_0: 0.8151 - precision_1: 0.7427 - recall_1: 0.5667 - F1_1: 0.6402 - val_loss: 0.8684 - val_accuracy: 0.4785 - val_precision_0: 0.8099 - val_recall_0: 0.5018 - val_F1_0: 0.6197 - val_precision_1: 0.1129 - val_recall_1: 0.3500 - val_F1_1: 0.1707
# Epoch 27/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4936 - accuracy: 0.7535 - precision_0: 0.7773 - recall_0: 0.8097 - F1_0: 0.7911 - precision_1: 0.7071 - recall_1: 0.6498 - F1_1: 0.6742 - val_loss: 0.8831 - val_accuracy: 0.5475 - val_precision_0: 0.8253 - val_recall_0: 0.5906 - val_F1_0: 0.6885 - val_precision_1: 0.1206 - val_recall_1: 0.3100 - val_F1_1: 0.1737
# Epoch 28/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4799 - accuracy: 0.7649 - precision_0: 0.7769 - recall_0: 0.8594 - F1_0: 0.8157 - precision_1: 0.7412 - recall_1: 0.6167 - F1_1: 0.6723 - val_loss: 0.8510 - val_accuracy: 0.5061 - val_precision_0: 0.8177 - val_recall_0: 0.5362 - val_F1_0: 0.6477 - val_precision_1: 0.1172 - val_recall_1: 0.3400 - val_F1_1: 0.1744
# Epoch 29/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4865 - accuracy: 0.7580 - precision_0: 0.7607 - recall_0: 0.8740 - F1_0: 0.8133 - precision_1: 0.7411 - recall_1: 0.5667 - F1_1: 0.6418 - val_loss: 0.9162 - val_accuracy: 0.5276 - val_precision_0: 0.8194 - val_recall_0: 0.5670 - val_F1_0: 0.6702 - val_precision_1: 0.1148 - val_recall_1: 0.3100 - val_F1_1: 0.1676
# Epoch 30/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4564 - accuracy: 0.7912 - precision_0: 0.7903 - recall_0: 0.8818 - F1_0: 0.8335 - precision_1: 0.7755 - recall_1: 0.6343 - F1_1: 0.6977 - val_loss: 0.9436 - val_accuracy: 0.4509 - val_precision_0: 0.7922 - val_recall_0: 0.4764 - val_F1_0: 0.5950 - val_precision_1: 0.0969 - val_recall_1: 0.3100 - val_F1_1: 0.1476
# Epoch 31/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4619 - accuracy: 0.7779 - precision_0: 0.7756 - recall_0: 0.8794 - F1_0: 0.8238 - precision_1: 0.7561 - recall_1: 0.5896 - F1_1: 0.6610 - val_loss: 0.7459 - val_accuracy: 0.6472 - val_precision_0: 0.8485 - val_recall_0: 0.7101 - val_F1_0: 0.7732 - val_precision_1: 0.1579 - val_recall_1: 0.3000 - val_F1_1: 0.2069
# Epoch 32/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4644 - accuracy: 0.7759 - precision_0: 0.7851 - recall_0: 0.8785 - F1_0: 0.8290 - precision_1: 0.7619 - recall_1: 0.6175 - F1_1: 0.6817 - val_loss: 0.7635 - val_accuracy: 0.6656 - val_precision_0: 0.8523 - val_recall_0: 0.7319 - val_F1_0: 0.7875 - val_precision_1: 0.1685 - val_recall_1: 0.3000 - val_F1_1: 0.2158
# Epoch 33/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4398 - accuracy: 0.8042 - precision_0: 0.8043 - recall_0: 0.9054 - F1_0: 0.8515 - precision_1: 0.8111 - recall_1: 0.6435 - F1_1: 0.7157 - val_loss: 1.3444 - val_accuracy: 0.4985 - val_precision_0: 0.8223 - val_recall_0: 0.5199 - val_F1_0: 0.6371 - val_precision_1: 0.1254 - val_recall_1: 0.3800 - val_F1_1: 0.1886
# Epoch 34/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4412 - accuracy: 0.7951 - precision_0: 0.7924 - recall_0: 0.8862 - F1_0: 0.8364 - precision_1: 0.7844 - recall_1: 0.6379 - F1_1: 0.7029 - val_loss: 1.0232 - val_accuracy: 0.6426 - val_precision_0: 0.8490 - val_recall_0: 0.7029 - val_F1_0: 0.7691 - val_precision_1: 0.1590 - val_recall_1: 0.3100 - val_F1_1: 0.2102
# Epoch 35/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4322 - accuracy: 0.7997 - precision_0: 0.7943 - recall_0: 0.9223 - F1_0: 0.8531 - precision_1: 0.8379 - recall_1: 0.6189 - F1_1: 0.7096 - val_loss: 1.0982 - val_accuracy: 0.6181 - val_precision_0: 0.8435 - val_recall_0: 0.6739 - val_F1_0: 0.7492 - val_precision_1: 0.1469 - val_recall_1: 0.3100 - val_F1_1: 0.1994
# Epoch 36/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4226 - accuracy: 0.8169 - precision_0: 0.8070 - recall_0: 0.9153 - F1_0: 0.8576 - precision_1: 0.8215 - recall_1: 0.6389 - F1_1: 0.7182 - val_loss: 1.2902 - val_accuracy: 0.5936 - val_precision_0: 0.8376 - val_recall_0: 0.6449 - val_F1_0: 0.7288 - val_precision_1: 0.1366 - val_recall_1: 0.3100 - val_F1_1: 0.1896
# Epoch 37/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4239 - accuracy: 0.8091 - precision_0: 0.7958 - recall_0: 0.9149 - F1_0: 0.8510 - precision_1: 0.8322 - recall_1: 0.6419 - F1_1: 0.7241 - val_loss: 0.9743 - val_accuracy: 0.6334 - val_precision_0: 0.8455 - val_recall_0: 0.6938 - val_F1_0: 0.7622 - val_precision_1: 0.1508 - val_recall_1: 0.3000 - val_F1_1: 0.2007
# Epoch 38/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4328 - accuracy: 0.8000 - precision_0: 0.7937 - recall_0: 0.9109 - F1_0: 0.8481 - precision_1: 0.8013 - recall_1: 0.5983 - F1_1: 0.6838 - val_loss: 1.1336 - val_accuracy: 0.6365 - val_precision_0: 0.8477 - val_recall_0: 0.6957 - val_F1_0: 0.7642 - val_precision_1: 0.1558 - val_recall_1: 0.3100 - val_F1_1: 0.2074
# Epoch 39/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4008 - accuracy: 0.8237 - precision_0: 0.8028 - recall_0: 0.9196 - F1_0: 0.8571 - precision_1: 0.8387 - recall_1: 0.6482 - F1_1: 0.7303 - val_loss: 1.4391 - val_accuracy: 0.6043 - val_precision_0: 0.8403 - val_recall_0: 0.6576 - val_F1_0: 0.7378 - val_precision_1: 0.1409 - val_recall_1: 0.3100 - val_F1_1: 0.1938
# Epoch 40/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4122 - accuracy: 0.8159 - precision_0: 0.8234 - recall_0: 0.9116 - F1_0: 0.8651 - precision_1: 0.8298 - recall_1: 0.6859 - F1_1: 0.7506 - val_loss: 1.6390 - val_accuracy: 0.4877 - val_precision_0: 0.9037 - val_recall_0: 0.4420 - val_F1_0: 0.5937 - val_precision_1: 0.1937 - val_recall_1: 0.7400 - val_F1_1: 0.3071
# Epoch 41/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3928 - accuracy: 0.8221 - precision_0: 0.8192 - recall_0: 0.8977 - F1_0: 0.8560 - precision_1: 0.8229 - recall_1: 0.6958 - F1_1: 0.7528 - val_loss: 1.3957 - val_accuracy: 0.6242 - val_precision_0: 0.8465 - val_recall_0: 0.6793 - val_F1_0: 0.7538 - val_precision_1: 0.1531 - val_recall_1: 0.3200 - val_F1_1: 0.2071
# Epoch 42/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4174 - accuracy: 0.8046 - precision_0: 0.8141 - recall_0: 0.9145 - F1_0: 0.8613 - precision_1: 0.8199 - recall_1: 0.6500 - F1_1: 0.7248 - val_loss: 1.4168 - val_accuracy: 0.5966 - val_precision_0: 0.8715 - val_recall_0: 0.6141 - val_F1_0: 0.7205 - val_precision_1: 0.1901 - val_recall_1: 0.5000 - val_F1_1: 0.2755
# Epoch 43/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3794 - accuracy: 0.8341 - precision_0: 0.8259 - recall_0: 0.9022 - F1_0: 0.8622 - precision_1: 0.8323 - recall_1: 0.7141 - F1_1: 0.7681 - val_loss: 1.5552 - val_accuracy: 0.4923 - val_precision_0: 0.8130 - val_recall_0: 0.5199 - val_F1_0: 0.6343 - val_precision_1: 0.1137 - val_recall_1: 0.3400 - val_F1_1: 0.1704
# Epoch 44/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3793 - accuracy: 0.8289 - precision_0: 0.8335 - recall_0: 0.9083 - F1_0: 0.8690 - precision_1: 0.8247 - recall_1: 0.7009 - F1_1: 0.7570 - val_loss: 1.3317 - val_accuracy: 0.5660 - val_precision_0: 0.8305 - val_recall_0: 0.6123 - val_F1_0: 0.7049 - val_precision_1: 0.1265 - val_recall_1: 0.3100 - val_F1_1: 0.1797
# Epoch 45/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3769 - accuracy: 0.8338 - precision_0: 0.8203 - recall_0: 0.9244 - F1_0: 0.8692 - precision_1: 0.8580 - recall_1: 0.6912 - F1_1: 0.7654 - val_loss: 1.2083 - val_accuracy: 0.6472 - val_precision_0: 0.8626 - val_recall_0: 0.6938 - val_F1_0: 0.7691 - val_precision_1: 0.1875 - val_recall_1: 0.3900 - val_F1_1: 0.2532
# Epoch 46/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3743 - accuracy: 0.8325 - precision_0: 0.8226 - recall_0: 0.9274 - F1_0: 0.8716 - precision_1: 0.8621 - recall_1: 0.6940 - F1_1: 0.7684 - val_loss: 1.4267 - val_accuracy: 0.5215 - val_precision_0: 0.8175 - val_recall_0: 0.5598 - val_F1_0: 0.6645 - val_precision_1: 0.1131 - val_recall_1: 0.3100 - val_F1_1: 0.1658
# Epoch 47/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3474 - accuracy: 0.8433 - precision_0: 0.8427 - recall_0: 0.9239 - F1_0: 0.8814 - precision_1: 0.8555 - recall_1: 0.7234 - F1_1: 0.7839 - val_loss: 1.5052 - val_accuracy: 0.5291 - val_precision_0: 0.8215 - val_recall_0: 0.5670 - val_F1_0: 0.6710 - val_precision_1: 0.1181 - val_recall_1: 0.3200 - val_F1_1: 0.1725
# Epoch 48/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3884 - accuracy: 0.8254 - precision_0: 0.8296 - recall_0: 0.9050 - F1_0: 0.8656 - precision_1: 0.8233 - recall_1: 0.7036 - F1_1: 0.7584 - val_loss: 1.5131 - val_accuracy: 0.5813 - val_precision_0: 0.8329 - val_recall_0: 0.6322 - val_F1_0: 0.7188 - val_precision_1: 0.1288 - val_recall_1: 0.3000 - val_F1_1: 0.1802
# Epoch 49/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3547 - accuracy: 0.8475 - precision_0: 0.8336 - recall_0: 0.9298 - F1_0: 0.8790 - precision_1: 0.8612 - recall_1: 0.7011 - F1_1: 0.7723 - val_loss: 1.4003 - val_accuracy: 0.5552 - val_precision_0: 0.8291 - val_recall_0: 0.5978 - val_F1_0: 0.6947 - val_precision_1: 0.1260 - val_recall_1: 0.3200 - val_F1_1: 0.1808
# Epoch 50/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3328 - accuracy: 0.8494 - precision_0: 0.8388 - recall_0: 0.9172 - F1_0: 0.8762 - precision_1: 0.8436 - recall_1: 0.7169 - F1_1: 0.7751 - val_loss: 1.7232 - val_accuracy: 0.4939 - val_precision_0: 0.8101 - val_recall_0: 0.5254 - val_F1_0: 0.6374 - val_precision_1: 0.1088 - val_recall_1: 0.3200 - val_F1_1: 0.1624
# Epoch 51/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3486 - accuracy: 0.8423 - precision_0: 0.8299 - recall_0: 0.9316 - F1_0: 0.8777 - precision_1: 0.8702 - recall_1: 0.7054 - F1_1: 0.7789 - val_loss: 1.6064 - val_accuracy: 0.5859 - val_precision_0: 0.8357 - val_recall_0: 0.6359 - val_F1_0: 0.7222 - val_precision_1: 0.1336 - val_recall_1: 0.3100 - val_F1_1: 0.1867
# Epoch 52/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3462 - accuracy: 0.8452 - precision_0: 0.8372 - recall_0: 0.9170 - F1_0: 0.8752 - precision_1: 0.8536 - recall_1: 0.7301 - F1_1: 0.7869 - val_loss: 1.5266 - val_accuracy: 0.4724 - val_precision_0: 0.8190 - val_recall_0: 0.4837 - val_F1_0: 0.6082 - val_precision_1: 0.1258 - val_recall_1: 0.4100 - val_F1_1: 0.1925
# Epoch 53/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3214 - accuracy: 0.8598 - precision_0: 0.8786 - recall_0: 0.9238 - F1_0: 0.9005 - precision_1: 0.8642 - recall_1: 0.7907 - F1_1: 0.8256 - val_loss: 1.7478 - val_accuracy: 0.5782 - val_precision_0: 0.8354 - val_recall_0: 0.6250 - val_F1_0: 0.7150 - val_precision_1: 0.1339 - val_recall_1: 0.3200 - val_F1_1: 0.1888
# Epoch 54/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3159 - accuracy: 0.8595 - precision_0: 0.8572 - recall_0: 0.9203 - F1_0: 0.8876 - precision_1: 0.8470 - recall_1: 0.7418 - F1_1: 0.7907 - val_loss: 1.6921 - val_accuracy: 0.5767 - val_precision_0: 0.8350 - val_recall_0: 0.6232 - val_F1_0: 0.7137 - val_precision_1: 0.1333 - val_recall_1: 0.3200 - val_F1_1: 0.1882
# Epoch 55/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3575 - accuracy: 0.8400 - precision_0: 0.8539 - recall_0: 0.9091 - F1_0: 0.8806 - precision_1: 0.8368 - recall_1: 0.7502 - F1_1: 0.7910 - val_loss: 2.1040 - val_accuracy: 0.6074 - val_precision_0: 0.8426 - val_recall_0: 0.6594 - val_F1_0: 0.7398 - val_precision_1: 0.1455 - val_recall_1: 0.3200 - val_F1_1: 0.2000
# Epoch 56/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.3101 - accuracy: 0.8624 - precision_0: 0.8601 - recall_0: 0.9282 - F1_0: 0.8927 - precision_1: 0.8738 - recall_1: 0.7665 - F1_1: 0.8164 - val_loss: 1.5634 - val_accuracy: 0.5475 - val_precision_0: 0.8270 - val_recall_0: 0.5888 - val_F1_0: 0.6878 - val_precision_1: 0.1236 - val_recall_1: 0.3200 - val_F1_1: 0.1783
# Epoch 57/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2984 - accuracy: 0.8738 - precision_0: 0.8726 - recall_0: 0.9091 - F1_0: 0.8904 - precision_1: 0.8481 - recall_1: 0.7916 - F1_1: 0.8186 - val_loss: 1.4758 - val_accuracy: 0.5966 - val_precision_0: 0.8384 - val_recall_0: 0.6486 - val_F1_0: 0.7314 - val_precision_1: 0.1378 - val_recall_1: 0.3100 - val_F1_1: 0.1908
# Epoch 58/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.3076 - accuracy: 0.8712 - precision_0: 0.8652 - recall_0: 0.9104 - F1_0: 0.8871 - precision_1: 0.8390 - recall_1: 0.7656 - F1_1: 0.8001 - val_loss: 1.5115 - val_accuracy: 0.4494 - val_precision_0: 0.8006 - val_recall_0: 0.4656 - val_F1_0: 0.5888 - val_precision_1: 0.1088 - val_recall_1: 0.3600 - val_F1_1: 0.1671
# Epoch 59/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2878 - accuracy: 0.8758 - precision_0: 0.8733 - recall_0: 0.9166 - F1_0: 0.8944 - precision_1: 0.8636 - recall_1: 0.7973 - F1_1: 0.8289 - val_loss: 2.0969 - val_accuracy: 0.6150 - val_precision_0: 0.8444 - val_recall_0: 0.6685 - val_F1_0: 0.7462 - val_precision_1: 0.1488 - val_recall_1: 0.3200 - val_F1_1: 0.2032
# Epoch 60/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2748 - accuracy: 0.8839 - precision_0: 0.8777 - recall_0: 0.9357 - F1_0: 0.9056 - precision_1: 0.8810 - recall_1: 0.7816 - F1_1: 0.8275 - val_loss: 1.7259 - val_accuracy: 0.4985 - val_precision_0: 0.8169 - val_recall_0: 0.5254 - val_F1_0: 0.6395 - val_precision_1: 0.1178 - val_recall_1: 0.3500 - val_F1_1: 0.1763
# Epoch 61/150
# 97/97 [==============================] - 9s 92ms/step - loss: 0.2843 - accuracy: 0.8722 - precision_0: 0.8946 - recall_0: 0.9265 - F1_0: 0.9102 - precision_1: 0.8729 - recall_1: 0.8220 - F1_1: 0.8465 - val_loss: 2.0396 - val_accuracy: 0.6503 - val_precision_0: 0.8699 - val_recall_0: 0.6902 - val_F1_0: 0.7697 - val_precision_1: 0.2009 - val_recall_1: 0.4300 - val_F1_1: 0.2739
# Epoch 62/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2829 - accuracy: 0.8761 - precision_0: 0.8753 - recall_0: 0.9320 - F1_0: 0.9026 - precision_1: 0.8774 - recall_1: 0.7850 - F1_1: 0.8282 - val_loss: 1.8278 - val_accuracy: 0.6089 - val_precision_0: 0.8544 - val_recall_0: 0.6486 - val_F1_0: 0.7374 - val_precision_1: 0.1674 - val_recall_1: 0.3900 - val_F1_1: 0.2342
# Epoch 63/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2799 - accuracy: 0.8751 - precision_0: 0.8708 - recall_0: 0.9216 - F1_0: 0.8954 - precision_1: 0.8639 - recall_1: 0.7845 - F1_1: 0.8220 - val_loss: 2.2761 - val_accuracy: 0.5813 - val_precision_0: 0.8378 - val_recall_0: 0.6268 - val_F1_0: 0.7171 - val_precision_1: 0.1381 - val_recall_1: 0.3300 - val_F1_1: 0.1947
# Epoch 64/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2637 - accuracy: 0.8839 - precision_0: 0.8837 - recall_0: 0.9335 - F1_0: 0.9079 - precision_1: 0.8753 - recall_1: 0.7908 - F1_1: 0.8308 - val_loss: 1.9431 - val_accuracy: 0.4540 - val_precision_0: 0.8311 - val_recall_0: 0.4457 - val_F1_0: 0.5802 - val_precision_1: 0.1404 - val_recall_1: 0.5000 - val_F1_1: 0.2193
# Epoch 65/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2627 - accuracy: 0.8859 - precision_0: 0.8935 - recall_0: 0.9188 - F1_0: 0.9056 - precision_1: 0.8549 - recall_1: 0.8151 - F1_1: 0.8333 - val_loss: 2.2178 - val_accuracy: 0.5199 - val_precision_0: 0.8256 - val_recall_0: 0.5489 - val_F1_0: 0.6594 - val_precision_1: 0.1263 - val_recall_1: 0.3600 - val_F1_1: 0.1870
# Epoch 66/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2571 - accuracy: 0.8898 - precision_0: 0.8919 - recall_0: 0.9234 - F1_0: 0.9072 - precision_1: 0.8748 - recall_1: 0.8257 - F1_1: 0.8492 - val_loss: 1.9593 - val_accuracy: 0.5844 - val_precision_0: 0.8369 - val_recall_0: 0.6322 - val_F1_0: 0.7203 - val_precision_1: 0.1362 - val_recall_1: 0.3200 - val_F1_1: 0.1910
# Epoch 67/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2525 - accuracy: 0.8992 - precision_0: 0.9018 - recall_0: 0.9436 - F1_0: 0.9222 - precision_1: 0.8932 - recall_1: 0.8173 - F1_1: 0.8528 - val_loss: 1.8047 - val_accuracy: 0.5506 - val_precision_0: 0.8213 - val_recall_0: 0.5996 - val_F1_0: 0.6932 - val_precision_1: 0.1124 - val_recall_1: 0.2800 - val_F1_1: 0.1605
# Epoch 68/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2868 - accuracy: 0.8751 - precision_0: 0.8883 - recall_0: 0.9213 - F1_0: 0.9045 - precision_1: 0.8696 - recall_1: 0.8192 - F1_1: 0.8435 - val_loss: 2.2237 - val_accuracy: 0.4494 - val_precision_0: 0.8294 - val_recall_0: 0.4402 - val_F1_0: 0.5751 - val_precision_1: 0.1393 - val_recall_1: 0.5000 - val_F1_1: 0.2179
# Epoch 69/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2516 - accuracy: 0.8872 - precision_0: 0.8986 - recall_0: 0.9215 - F1_0: 0.9096 - precision_1: 0.8680 - recall_1: 0.8306 - F1_1: 0.8482 - val_loss: 2.1458 - val_accuracy: 0.5460 - val_precision_0: 0.8333 - val_recall_0: 0.5797 - val_F1_0: 0.6838 - val_precision_1: 0.1343 - val_recall_1: 0.3600 - val_F1_1: 0.1957
# Epoch 70/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2537 - accuracy: 0.8901 - precision_0: 0.8979 - recall_0: 0.9275 - F1_0: 0.9123 - precision_1: 0.8792 - recall_1: 0.8304 - F1_1: 0.8537 - val_loss: 2.5472 - val_accuracy: 0.5598 - val_precision_0: 0.8515 - val_recall_0: 0.5815 - val_F1_0: 0.6911 - val_precision_1: 0.1600 - val_recall_1: 0.4400 - val_F1_1: 0.2347
# Epoch 71/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2397 - accuracy: 0.9002 - precision_0: 0.8963 - recall_0: 0.9371 - F1_0: 0.9162 - precision_1: 0.8853 - recall_1: 0.8172 - F1_1: 0.8497 - val_loss: 1.7554 - val_accuracy: 0.5874 - val_precision_0: 0.8426 - val_recall_0: 0.6304 - val_F1_0: 0.7212 - val_precision_1: 0.1464 - val_recall_1: 0.3500 - val_F1_1: 0.2065
# Epoch 72/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2348 - accuracy: 0.8985 - precision_0: 0.9063 - recall_0: 0.9545 - F1_0: 0.9298 - precision_1: 0.9140 - recall_1: 0.8294 - F1_1: 0.8696 - val_loss: 1.6758 - val_accuracy: 0.4785 - val_precision_0: 0.8419 - val_recall_0: 0.4728 - val_F1_0: 0.6056 - val_precision_1: 0.1491 - val_recall_1: 0.5100 - val_F1_1: 0.2308
# Epoch 73/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2603 - accuracy: 0.8937 - precision_0: 0.9133 - recall_0: 0.9228 - F1_0: 0.9178 - precision_1: 0.8821 - recall_1: 0.8666 - F1_1: 0.8739 - val_loss: 2.1191 - val_accuracy: 0.6426 - val_precision_0: 0.8600 - val_recall_0: 0.6902 - val_F1_0: 0.7658 - val_precision_1: 0.1818 - val_recall_1: 0.3800 - val_F1_1: 0.2460
# Epoch 74/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2536 - accuracy: 0.8969 - precision_0: 0.8882 - recall_0: 0.9479 - F1_0: 0.9168 - precision_1: 0.9101 - recall_1: 0.8130 - F1_1: 0.8578 - val_loss: 1.2026 - val_accuracy: 0.5598 - val_precision_0: 0.8118 - val_recall_0: 0.6250 - val_F1_0: 0.7062 - val_precision_1: 0.0881 - val_recall_1: 0.2000 - val_F1_1: 0.1223
# Epoch 75/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2239 - accuracy: 0.9086 - precision_0: 0.9099 - recall_0: 0.9457 - F1_0: 0.9274 - precision_1: 0.9065 - recall_1: 0.8489 - F1_1: 0.8766 - val_loss: 2.7068 - val_accuracy: 0.5169 - val_precision_0: 0.8283 - val_recall_0: 0.5417 - val_F1_0: 0.6550 - val_precision_1: 0.1306 - val_recall_1: 0.3800 - val_F1_1: 0.1944
# Epoch 76/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2371 - accuracy: 0.8946 - precision_0: 0.8970 - recall_0: 0.9189 - F1_0: 0.9078 - precision_1: 0.8753 - recall_1: 0.8429 - F1_1: 0.8587 - val_loss: 2.7788 - val_accuracy: 0.5383 - val_precision_0: 0.8420 - val_recall_0: 0.5598 - val_F1_0: 0.6725 - val_precision_1: 0.1474 - val_recall_1: 0.4200 - val_F1_1: 0.2182
# Epoch 77/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.2242 - accuracy: 0.9024 - precision_0: 0.8974 - recall_0: 0.9418 - F1_0: 0.9190 - precision_1: 0.8983 - recall_1: 0.8265 - F1_1: 0.8608 - val_loss: 1.9262 - val_accuracy: 0.5874 - val_precision_0: 0.8619 - val_recall_0: 0.6105 - val_F1_0: 0.7147 - val_precision_1: 0.1762 - val_recall_1: 0.4600 - val_F1_1: 0.2548
# Epoch 78/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2415 - accuracy: 0.9002 - precision_0: 0.9149 - recall_0: 0.9338 - F1_0: 0.9242 - precision_1: 0.8912 - recall_1: 0.8615 - F1_1: 0.8759 - val_loss: 2.5692 - val_accuracy: 0.4908 - val_precision_0: 0.8254 - val_recall_0: 0.5054 - val_F1_0: 0.6270 - val_precision_1: 0.1306 - val_recall_1: 0.4100 - val_F1_1: 0.1981
# Epoch 79/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2072 - accuracy: 0.9132 - precision_0: 0.9140 - recall_0: 0.9417 - F1_0: 0.9276 - precision_1: 0.8987 - recall_1: 0.8522 - F1_1: 0.8744 - val_loss: 2.2035 - val_accuracy: 0.4187 - val_precision_0: 0.7932 - val_recall_0: 0.4239 - val_F1_0: 0.5525 - val_precision_1: 0.1092 - val_recall_1: 0.3900 - val_F1_1: 0.1707
# Epoch 80/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2463 - accuracy: 0.8930 - precision_0: 0.8953 - recall_0: 0.9221 - F1_0: 0.9085 - precision_1: 0.8636 - recall_1: 0.8205 - F1_1: 0.8414 - val_loss: 2.1854 - val_accuracy: 0.3727 - val_precision_0: 0.8150 - val_recall_0: 0.3351 - val_F1_0: 0.4750 - val_precision_1: 0.1365 - val_recall_1: 0.5800 - val_F1_1: 0.2210
# Epoch 81/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2231 - accuracy: 0.9099 - precision_0: 0.9122 - recall_0: 0.9428 - F1_0: 0.9271 - precision_1: 0.9026 - recall_1: 0.8526 - F1_1: 0.8765 - val_loss: 2.9841 - val_accuracy: 0.4433 - val_precision_0: 0.8363 - val_recall_0: 0.4257 - val_F1_0: 0.5642 - val_precision_1: 0.1456 - val_recall_1: 0.5400 - val_F1_1: 0.2293
# Epoch 82/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2388 - accuracy: 0.8989 - precision_0: 0.8921 - recall_0: 0.9271 - F1_0: 0.9092 - precision_1: 0.8725 - recall_1: 0.8159 - F1_1: 0.8431 - val_loss: 1.5643 - val_accuracy: 0.4463 - val_precision_0: 0.8051 - val_recall_0: 0.4565 - val_F1_0: 0.5827 - val_precision_1: 0.1150 - val_recall_1: 0.3900 - val_F1_1: 0.1777
# Epoch 83/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2110 - accuracy: 0.9154 - precision_0: 0.9194 - recall_0: 0.9486 - F1_0: 0.9338 - precision_1: 0.9163 - recall_1: 0.8709 - F1_1: 0.8930 - val_loss: 1.3697 - val_accuracy: 0.5690 - val_precision_0: 0.8613 - val_recall_0: 0.5851 - val_F1_0: 0.6969 - val_precision_1: 0.1733 - val_recall_1: 0.4800 - val_F1_1: 0.2546
# Epoch 84/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2228 - accuracy: 0.9028 - precision_0: 0.9175 - recall_0: 0.9384 - F1_0: 0.9278 - precision_1: 0.8840 - recall_1: 0.8469 - F1_1: 0.8649 - val_loss: 2.1099 - val_accuracy: 0.5982 - val_precision_0: 0.8519 - val_recall_0: 0.6359 - val_F1_0: 0.7282 - val_precision_1: 0.1625 - val_recall_1: 0.3900 - val_F1_1: 0.2294
# Epoch 85/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2005 - accuracy: 0.9154 - precision_0: 0.9264 - recall_0: 0.9485 - F1_0: 0.9373 - precision_1: 0.9137 - recall_1: 0.8784 - F1_1: 0.8957 - val_loss: 2.1843 - val_accuracy: 0.4893 - val_precision_0: 0.8230 - val_recall_0: 0.5054 - val_F1_0: 0.6263 - val_precision_1: 0.1278 - val_recall_1: 0.4000 - val_F1_1: 0.1937
# Epoch 86/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1933 - accuracy: 0.9200 - precision_0: 0.9267 - recall_0: 0.9493 - F1_0: 0.9379 - precision_1: 0.9087 - recall_1: 0.8698 - F1_1: 0.8888 - val_loss: 2.3672 - val_accuracy: 0.4233 - val_precision_0: 0.8077 - val_recall_0: 0.4185 - val_F1_0: 0.5513 - val_precision_1: 0.1230 - val_recall_1: 0.4500 - val_F1_1: 0.1931
# Epoch 87/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2265 - accuracy: 0.9057 - precision_0: 0.9077 - recall_0: 0.9369 - F1_0: 0.9219 - precision_1: 0.8849 - recall_1: 0.8363 - F1_1: 0.8592 - val_loss: 2.3185 - val_accuracy: 0.5598 - val_precision_0: 0.8304 - val_recall_0: 0.6033 - val_F1_0: 0.6988 - val_precision_1: 0.1275 - val_recall_1: 0.3200 - val_F1_1: 0.1823
# Epoch 88/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2079 - accuracy: 0.9145 - precision_0: 0.9205 - recall_0: 0.9513 - F1_0: 0.9356 - precision_1: 0.9197 - recall_1: 0.8709 - F1_1: 0.8945 - val_loss: 1.8119 - val_accuracy: 0.6089 - val_precision_0: 0.8631 - val_recall_0: 0.6395 - val_F1_0: 0.7347 - val_precision_1: 0.1811 - val_recall_1: 0.4400 - val_F1_1: 0.2566
# Epoch 89/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2081 - accuracy: 0.9138 - precision_0: 0.9211 - recall_0: 0.9430 - F1_0: 0.9319 - precision_1: 0.8972 - recall_1: 0.8606 - F1_1: 0.8784 - val_loss: 2.0597 - val_accuracy: 0.4847 - val_precision_0: 0.8273 - val_recall_0: 0.4946 - val_F1_0: 0.6190 - val_precision_1: 0.1335 - val_recall_1: 0.4300 - val_F1_1: 0.2038
# Epoch 90/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1943 - accuracy: 0.9213 - precision_0: 0.9316 - recall_0: 0.9585 - F1_0: 0.9448 - precision_1: 0.9298 - recall_1: 0.8867 - F1_1: 0.9076 - val_loss: 2.1478 - val_accuracy: 0.2837 - val_precision_0: 0.7429 - val_recall_0: 0.2355 - val_F1_0: 0.3576 - val_precision_1: 0.1153 - val_recall_1: 0.5500 - val_F1_1: 0.1906
# Epoch 91/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.4231 - accuracy: 0.8130 - precision_0: 0.8390 - recall_0: 0.8709 - F1_0: 0.8542 - precision_1: 0.7728 - recall_1: 0.7240 - F1_1: 0.7465 - val_loss: 0.9858 - val_accuracy: 0.6319 - val_precision_0: 0.8824 - val_recall_0: 0.6522 - val_F1_0: 0.7500 - val_precision_1: 0.2131 - val_recall_1: 0.5200 - val_F1_1: 0.3023
# Epoch 92/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2237 - accuracy: 0.9083 - precision_0: 0.9012 - recall_0: 0.9384 - F1_0: 0.9194 - precision_1: 0.8893 - recall_1: 0.8265 - F1_1: 0.8566 - val_loss: 1.5528 - val_accuracy: 0.5414 - val_precision_0: 0.8373 - val_recall_0: 0.5688 - val_F1_0: 0.6775 - val_precision_1: 0.1408 - val_recall_1: 0.3900 - val_F1_1: 0.2069
# Epoch 93/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2016 - accuracy: 0.9158 - precision_0: 0.9099 - recall_0: 0.9512 - F1_0: 0.9301 - precision_1: 0.9189 - recall_1: 0.8542 - F1_1: 0.8852 - val_loss: 1.7645 - val_accuracy: 0.5460 - val_precision_0: 0.8351 - val_recall_0: 0.5779 - val_F1_0: 0.6831 - val_precision_1: 0.1370 - val_recall_1: 0.3700 - val_F1_1: 0.2000
# Epoch 94/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1992 - accuracy: 0.9190 - precision_0: 0.9221 - recall_0: 0.9531 - F1_0: 0.9373 - precision_1: 0.9131 - recall_1: 0.8592 - F1_1: 0.8852 - val_loss: 1.8672 - val_accuracy: 0.5245 - val_precision_0: 0.8306 - val_recall_0: 0.5507 - val_F1_0: 0.6623 - val_precision_1: 0.1329 - val_recall_1: 0.3800 - val_F1_1: 0.1969
# Epoch 95/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1853 - accuracy: 0.9200 - precision_0: 0.9250 - recall_0: 0.9512 - F1_0: 0.9379 - precision_1: 0.9167 - recall_1: 0.8737 - F1_1: 0.8946 - val_loss: 1.8747 - val_accuracy: 0.5322 - val_precision_0: 0.8421 - val_recall_0: 0.5507 - val_F1_0: 0.6659 - val_precision_1: 0.1478 - val_recall_1: 0.4300 - val_F1_1: 0.2199
# Epoch 96/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1821 - accuracy: 0.9294 - precision_0: 0.9319 - recall_0: 0.9595 - F1_0: 0.9455 - precision_1: 0.9293 - recall_1: 0.8837 - F1_1: 0.9059 - val_loss: 2.6672 - val_accuracy: 0.4479 - val_precision_0: 0.8243 - val_recall_0: 0.4420 - val_F1_0: 0.5755 - val_precision_1: 0.1348 - val_recall_1: 0.4800 - val_F1_1: 0.2105
# Epoch 97/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1925 - accuracy: 0.9193 - precision_0: 0.9295 - recall_0: 0.9305 - F1_0: 0.9296 - precision_1: 0.8824 - recall_1: 0.8806 - F1_1: 0.8801 - val_loss: 1.9379 - val_accuracy: 0.5383 - val_precision_0: 0.8260 - val_recall_0: 0.5761 - val_F1_0: 0.6788 - val_precision_1: 0.1236 - val_recall_1: 0.3300 - val_F1_1: 0.1798
# Epoch 98/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1951 - accuracy: 0.9210 - precision_0: 0.9310 - recall_0: 0.9594 - F1_0: 0.9449 - precision_1: 0.9277 - recall_1: 0.8780 - F1_1: 0.9020 - val_loss: 1.5472 - val_accuracy: 0.5859 - val_precision_0: 0.8439 - val_recall_0: 0.6268 - val_F1_0: 0.7193 - val_precision_1: 0.1488 - val_recall_1: 0.3600 - val_F1_1: 0.2105
# Epoch 99/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2066 - accuracy: 0.9145 - precision_0: 0.9053 - recall_0: 0.9463 - F1_0: 0.9252 - precision_1: 0.9065 - recall_1: 0.8397 - F1_1: 0.8714 - val_loss: 2.2414 - val_accuracy: 0.5276 - val_precision_0: 0.8408 - val_recall_0: 0.5453 - val_F1_0: 0.6615 - val_precision_1: 0.1463 - val_recall_1: 0.4300 - val_F1_1: 0.2183
# Epoch 100/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1951 - accuracy: 0.9177 - precision_0: 0.9249 - recall_0: 0.9557 - F1_0: 0.9400 - precision_1: 0.9231 - recall_1: 0.8730 - F1_1: 0.8973 - val_loss: 2.3643 - val_accuracy: 0.4663 - val_precision_0: 0.8072 - val_recall_0: 0.4855 - val_F1_0: 0.6063 - val_precision_1: 0.1125 - val_recall_1: 0.3600 - val_F1_1: 0.1714
# Epoch 101/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2245 - accuracy: 0.9154 - precision_0: 0.9211 - recall_0: 0.9537 - F1_0: 0.9371 - precision_1: 0.9145 - recall_1: 0.8580 - F1_1: 0.8853 - val_loss: 1.1978 - val_accuracy: 0.4985 - val_precision_0: 0.8205 - val_recall_0: 0.5217 - val_F1_0: 0.6379 - val_precision_1: 0.1229 - val_recall_1: 0.3700 - val_F1_1: 0.1845
# Epoch 102/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2384 - accuracy: 0.9024 - precision_0: 0.8950 - recall_0: 0.9217 - F1_0: 0.9079 - precision_1: 0.8544 - recall_1: 0.8099 - F1_1: 0.8310 - val_loss: 2.0767 - val_accuracy: 0.5000 - val_precision_0: 0.8717 - val_recall_0: 0.4801 - val_F1_0: 0.6192 - val_precision_1: 0.1753 - val_recall_1: 0.6100 - val_F1_1: 0.2723
# Epoch 103/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2090 - accuracy: 0.9161 - precision_0: 0.9140 - recall_0: 0.9360 - F1_0: 0.9248 - precision_1: 0.8971 - recall_1: 0.8635 - F1_1: 0.8798 - val_loss: 1.2320 - val_accuracy: 0.5844 - val_precision_0: 0.8707 - val_recall_0: 0.5978 - val_F1_0: 0.7089 - val_precision_1: 0.1868 - val_recall_1: 0.5100 - val_F1_1: 0.2735
# Epoch 104/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1829 - accuracy: 0.9301 - precision_0: 0.9373 - recall_0: 0.9549 - F1_0: 0.9460 - precision_1: 0.9278 - recall_1: 0.9004 - F1_1: 0.9137 - val_loss: 1.8508 - val_accuracy: 0.5736 - val_precision_0: 0.8586 - val_recall_0: 0.5942 - val_F1_0: 0.7024 - val_precision_1: 0.1704 - val_recall_1: 0.4600 - val_F1_1: 0.2486
# Epoch 105/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1895 - accuracy: 0.9236 - precision_0: 0.9389 - recall_0: 0.9436 - F1_0: 0.9412 - precision_1: 0.9087 - recall_1: 0.8999 - F1_1: 0.9041 - val_loss: 1.7131 - val_accuracy: 0.4617 - val_precision_0: 0.8170 - val_recall_0: 0.4692 - val_F1_0: 0.5961 - val_precision_1: 0.1254 - val_recall_1: 0.4200 - val_F1_1: 0.1931
# Epoch 106/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1570 - accuracy: 0.9356 - precision_0: 0.9440 - recall_0: 0.9673 - F1_0: 0.9555 - precision_1: 0.9453 - recall_1: 0.9081 - F1_1: 0.9263 - val_loss: 1.6755 - val_accuracy: 0.4156 - val_precision_0: 0.8021 - val_recall_0: 0.4112 - val_F1_0: 0.5437 - val_precision_1: 0.1192 - val_recall_1: 0.4400 - val_F1_1: 0.1876
# Epoch 107/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1977 - accuracy: 0.9180 - precision_0: 0.9303 - recall_0: 0.9544 - F1_0: 0.9422 - precision_1: 0.9196 - recall_1: 0.8791 - F1_1: 0.8987 - val_loss: 1.7850 - val_accuracy: 0.3758 - val_precision_0: 0.7509 - val_recall_0: 0.3931 - val_F1_0: 0.5161 - val_precision_1: 0.0771 - val_recall_1: 0.2800 - val_F1_1: 0.1210
# Epoch 108/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1674 - accuracy: 0.9350 - precision_0: 0.9360 - recall_0: 0.9603 - F1_0: 0.9480 - precision_1: 0.9371 - recall_1: 0.8995 - F1_1: 0.9178 - val_loss: 1.9410 - val_accuracy: 0.4862 - val_precision_0: 0.8258 - val_recall_0: 0.4982 - val_F1_0: 0.6215 - val_precision_1: 0.1317 - val_recall_1: 0.4200 - val_F1_1: 0.2005
# Epoch 109/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1654 - accuracy: 0.9340 - precision_0: 0.9294 - recall_0: 0.9494 - F1_0: 0.9392 - precision_1: 0.9149 - recall_1: 0.8801 - F1_1: 0.8968 - val_loss: 2.1748 - val_accuracy: 0.4693 - val_precision_0: 0.8179 - val_recall_0: 0.4801 - val_F1_0: 0.6050 - val_precision_1: 0.1250 - val_recall_1: 0.4100 - val_F1_1: 0.1916
# Epoch 110/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1673 - accuracy: 0.9317 - precision_0: 0.9435 - recall_0: 0.9593 - F1_0: 0.9513 - precision_1: 0.9331 - recall_1: 0.9069 - F1_1: 0.9197 - val_loss: 2.5399 - val_accuracy: 0.3681 - val_precision_0: 0.7893 - val_recall_0: 0.3460 - val_F1_0: 0.4811 - val_precision_1: 0.1195 - val_recall_1: 0.4900 - val_F1_1: 0.1922
# Epoch 111/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1749 - accuracy: 0.9307 - precision_0: 0.9302 - recall_0: 0.9419 - F1_0: 0.9358 - precision_1: 0.9060 - recall_1: 0.8846 - F1_1: 0.8949 - val_loss: 2.3248 - val_accuracy: 0.4647 - val_precision_0: 0.8202 - val_recall_0: 0.4710 - val_F1_0: 0.5984 - val_precision_1: 0.1284 - val_recall_1: 0.4300 - val_F1_1: 0.1977
# Epoch 112/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1600 - accuracy: 0.9324 - precision_0: 0.9412 - recall_0: 0.9564 - F1_0: 0.9487 - precision_1: 0.9260 - recall_1: 0.9015 - F1_1: 0.9135 - val_loss: 2.7030 - val_accuracy: 0.3574 - val_precision_0: 0.7782 - val_recall_0: 0.3370 - val_F1_0: 0.4703 - val_precision_1: 0.1138 - val_recall_1: 0.4700 - val_F1_1: 0.1832
# Epoch 113/150
# 97/97 [==============================] - 9s 90ms/step - loss: 0.1479 - accuracy: 0.9431 - precision_0: 0.9560 - recall_0: 0.9654 - F1_0: 0.9606 - precision_1: 0.9441 - recall_1: 0.9290 - F1_1: 0.9364 - val_loss: 2.1805 - val_accuracy: 0.4739 - val_precision_0: 0.8339 - val_recall_0: 0.4728 - val_F1_0: 0.6035 - val_precision_1: 0.1416 - val_recall_1: 0.4800 - val_F1_1: 0.2187
# Epoch 114/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1628 - accuracy: 0.9330 - precision_0: 0.9363 - recall_0: 0.9576 - F1_0: 0.9468 - precision_1: 0.9322 - recall_1: 0.9001 - F1_1: 0.9158 - val_loss: 1.8509 - val_accuracy: 0.5491 - val_precision_0: 0.8449 - val_recall_0: 0.5725 - val_F1_0: 0.6825 - val_precision_1: 0.1511 - val_recall_1: 0.4200 - val_F1_1: 0.2222
# Epoch 115/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1685 - accuracy: 0.9330 - precision_0: 0.9314 - recall_0: 0.9592 - F1_0: 0.9451 - precision_1: 0.9284 - recall_1: 0.8812 - F1_1: 0.9039 - val_loss: 2.3204 - val_accuracy: 0.4877 - val_precision_0: 0.8187 - val_recall_0: 0.5072 - val_F1_0: 0.6264 - val_precision_1: 0.1226 - val_recall_1: 0.3800 - val_F1_1: 0.1854
# Epoch 116/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1376 - accuracy: 0.9444 - precision_0: 0.9489 - recall_0: 0.9649 - F1_0: 0.9568 - precision_1: 0.9431 - recall_1: 0.9179 - F1_1: 0.9303 - val_loss: 3.2973 - val_accuracy: 0.4663 - val_precision_0: 0.8168 - val_recall_0: 0.4764 - val_F1_0: 0.6018 - val_precision_1: 0.1242 - val_recall_1: 0.4100 - val_F1_1: 0.1907
# Epoch 117/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1543 - accuracy: 0.9382 - precision_0: 0.9472 - recall_0: 0.9659 - F1_0: 0.9564 - precision_1: 0.9417 - recall_1: 0.9110 - F1_1: 0.9260 - val_loss: 2.4141 - val_accuracy: 0.4816 - val_precision_0: 0.8408 - val_recall_0: 0.4783 - val_F1_0: 0.6097 - val_precision_1: 0.1479 - val_recall_1: 0.5000 - val_F1_1: 0.2283
# Epoch 118/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1415 - accuracy: 0.9424 - precision_0: 0.9394 - recall_0: 0.9604 - F1_0: 0.9498 - precision_1: 0.9341 - recall_1: 0.9008 - F1_1: 0.9171 - val_loss: 2.9337 - val_accuracy: 0.4433 - val_precision_0: 0.8161 - val_recall_0: 0.4420 - val_F1_0: 0.5734 - val_precision_1: 0.1275 - val_recall_1: 0.4500 - val_F1_1: 0.1987
# Epoch 119/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1681 - accuracy: 0.9262 - precision_0: 0.9354 - recall_0: 0.9487 - F1_0: 0.9420 - precision_1: 0.9165 - recall_1: 0.8948 - F1_1: 0.9054 - val_loss: 1.7725 - val_accuracy: 0.5997 - val_precision_0: 0.8665 - val_recall_0: 0.6232 - val_F1_0: 0.7250 - val_precision_1: 0.1843 - val_recall_1: 0.4700 - val_F1_1: 0.2648
# Epoch 120/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1651 - accuracy: 0.9353 - precision_0: 0.9273 - recall_0: 0.9528 - F1_0: 0.9396 - precision_1: 0.9217 - recall_1: 0.8815 - F1_1: 0.9005 - val_loss: 3.1135 - val_accuracy: 0.3834 - val_precision_0: 0.7799 - val_recall_0: 0.3786 - val_F1_0: 0.5098 - val_precision_1: 0.1068 - val_recall_1: 0.4100 - val_F1_1: 0.1694
# Epoch 121/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1539 - accuracy: 0.9389 - precision_0: 0.9433 - recall_0: 0.9484 - F1_0: 0.9458 - precision_1: 0.9192 - recall_1: 0.9110 - F1_1: 0.9149 - val_loss: 2.7075 - val_accuracy: 0.4294 - val_precision_0: 0.8125 - val_recall_0: 0.4239 - val_F1_0: 0.5571 - val_precision_1: 0.1264 - val_recall_1: 0.4600 - val_F1_1: 0.1983
# Epoch 122/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1485 - accuracy: 0.9398 - precision_0: 0.9394 - recall_0: 0.9529 - F1_0: 0.9461 - precision_1: 0.9252 - recall_1: 0.9042 - F1_1: 0.9145 - val_loss: 2.5290 - val_accuracy: 0.4279 - val_precision_0: 0.7841 - val_recall_0: 0.4475 - val_F1_0: 0.5698 - val_precision_1: 0.0950 - val_recall_1: 0.3200 - val_F1_1: 0.1465
# Epoch 123/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1547 - accuracy: 0.9389 - precision_0: 0.9468 - recall_0: 0.9672 - F1_0: 0.9568 - precision_1: 0.9469 - recall_1: 0.9153 - F1_1: 0.9307 - val_loss: 2.9985 - val_accuracy: 0.5414 - val_precision_0: 0.8428 - val_recall_0: 0.5634 - val_F1_0: 0.6754 - val_precision_1: 0.1484 - val_recall_1: 0.4200 - val_F1_1: 0.2193
# Epoch 124/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1622 - accuracy: 0.9343 - precision_0: 0.9386 - recall_0: 0.9428 - F1_0: 0.9406 - precision_1: 0.9086 - recall_1: 0.9014 - F1_1: 0.9049 - val_loss: 2.2924 - val_accuracy: 0.4693 - val_precision_0: 0.8259 - val_recall_0: 0.4728 - val_F1_0: 0.6014 - val_precision_1: 0.1339 - val_recall_1: 0.4500 - val_F1_1: 0.2064
# Epoch 125/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1413 - accuracy: 0.9424 - precision_0: 0.9510 - recall_0: 0.9676 - F1_0: 0.9592 - precision_1: 0.9462 - recall_1: 0.9196 - F1_1: 0.9327 - val_loss: 2.4719 - val_accuracy: 0.4877 - val_precision_0: 0.8283 - val_recall_0: 0.4982 - val_F1_0: 0.6222 - val_precision_1: 0.1344 - val_recall_1: 0.4300 - val_F1_1: 0.2048
# Epoch 126/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1267 - accuracy: 0.9480 - precision_0: 0.9560 - recall_0: 0.9657 - F1_0: 0.9608 - precision_1: 0.9447 - recall_1: 0.9289 - F1_1: 0.9366 - val_loss: 3.1012 - val_accuracy: 0.3666 - val_precision_0: 0.7747 - val_recall_0: 0.3551 - val_F1_0: 0.4870 - val_precision_1: 0.1078 - val_recall_1: 0.4300 - val_F1_1: 0.1723
# Epoch 127/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1861 - accuracy: 0.9275 - precision_0: 0.9426 - recall_0: 0.9557 - F1_0: 0.9490 - precision_1: 0.9230 - recall_1: 0.9047 - F1_1: 0.9132 - val_loss: 3.2613 - val_accuracy: 0.3972 - val_precision_0: 0.7912 - val_recall_0: 0.3913 - val_F1_0: 0.5236 - val_precision_1: 0.1135 - val_recall_1: 0.4300 - val_F1_1: 0.1795
# Epoch 128/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1815 - accuracy: 0.9265 - precision_0: 0.9382 - recall_0: 0.9542 - F1_0: 0.9461 - precision_1: 0.9219 - recall_1: 0.8960 - F1_1: 0.9087 - val_loss: 1.6621 - val_accuracy: 0.3834 - val_precision_0: 0.7622 - val_recall_0: 0.3949 - val_F1_0: 0.5203 - val_precision_1: 0.0874 - val_recall_1: 0.3200 - val_F1_1: 0.1373
# Epoch 129/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1549 - accuracy: 0.9424 - precision_0: 0.9468 - recall_0: 0.9504 - F1_0: 0.9485 - precision_1: 0.9222 - recall_1: 0.9160 - F1_1: 0.9189 - val_loss: 2.7297 - val_accuracy: 0.4724 - val_precision_0: 0.8133 - val_recall_0: 0.4891 - val_F1_0: 0.6109 - val_precision_1: 0.1187 - val_recall_1: 0.3800 - val_F1_1: 0.1810
# Epoch 130/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1578 - accuracy: 0.9337 - precision_0: 0.9392 - recall_0: 0.9530 - F1_0: 0.9459 - precision_1: 0.9279 - recall_1: 0.9061 - F1_1: 0.9167 - val_loss: 2.8510 - val_accuracy: 0.3650 - val_precision_0: 0.7805 - val_recall_0: 0.3478 - val_F1_0: 0.4812 - val_precision_1: 0.1133 - val_recall_1: 0.4600 - val_F1_1: 0.1818
# Epoch 131/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1321 - accuracy: 0.9434 - precision_0: 0.9520 - recall_0: 0.9604 - F1_0: 0.9561 - precision_1: 0.9424 - recall_1: 0.9287 - F1_1: 0.9354 - val_loss: 3.1715 - val_accuracy: 0.4279 - val_precision_0: 0.8076 - val_recall_0: 0.4257 - val_F1_0: 0.5575 - val_precision_1: 0.1219 - val_recall_1: 0.4400 - val_F1_1: 0.1909
# Epoch 132/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1372 - accuracy: 0.9460 - precision_0: 0.9444 - recall_0: 0.9599 - F1_0: 0.9520 - precision_1: 0.9353 - recall_1: 0.9111 - F1_1: 0.9230 - val_loss: 2.6008 - val_accuracy: 0.4847 - val_precision_0: 0.8121 - val_recall_0: 0.5091 - val_F1_0: 0.6258 - val_precision_1: 0.1144 - val_recall_1: 0.3500 - val_F1_1: 0.1724
# Epoch 133/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1223 - accuracy: 0.9535 - precision_0: 0.9572 - recall_0: 0.9735 - F1_0: 0.9652 - precision_1: 0.9550 - recall_1: 0.9284 - F1_1: 0.9414 - val_loss: 2.7589 - val_accuracy: 0.3957 - val_precision_0: 0.7992 - val_recall_0: 0.3822 - val_F1_0: 0.5172 - val_precision_1: 0.1211 - val_recall_1: 0.4700 - val_F1_1: 0.1926
# Epoch 134/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1192 - accuracy: 0.9561 - precision_0: 0.9587 - recall_0: 0.9688 - F1_0: 0.9637 - precision_1: 0.9479 - recall_1: 0.9316 - F1_1: 0.9396 - val_loss: 3.6402 - val_accuracy: 0.3206 - val_precision_0: 0.7319 - val_recall_0: 0.3116 - val_F1_0: 0.4371 - val_precision_1: 0.0887 - val_recall_1: 0.3700 - val_F1_1: 0.1431
# Epoch 135/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1307 - accuracy: 0.9499 - precision_0: 0.9524 - recall_0: 0.9498 - F1_0: 0.9509 - precision_1: 0.9232 - recall_1: 0.9248 - F1_1: 0.9237 - val_loss: 2.9704 - val_accuracy: 0.4202 - val_precision_0: 0.8085 - val_recall_0: 0.4130 - val_F1_0: 0.5468 - val_precision_1: 0.1243 - val_recall_1: 0.4600 - val_F1_1: 0.1957
# Epoch 136/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1578 - accuracy: 0.9376 - precision_0: 0.9493 - recall_0: 0.9620 - F1_0: 0.9556 - precision_1: 0.9390 - recall_1: 0.9189 - F1_1: 0.9288 - val_loss: 2.6277 - val_accuracy: 0.3620 - val_precision_0: 0.7636 - val_recall_0: 0.3569 - val_F1_0: 0.4864 - val_precision_1: 0.0990 - val_recall_1: 0.3900 - val_F1_1: 0.1579
# Epoch 137/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1226 - accuracy: 0.9506 - precision_0: 0.9513 - recall_0: 0.9719 - F1_0: 0.9614 - precision_1: 0.9537 - recall_1: 0.9209 - F1_1: 0.9370 - val_loss: 2.5544 - val_accuracy: 0.4433 - val_precision_0: 0.8000 - val_recall_0: 0.4565 - val_F1_0: 0.5813 - val_precision_1: 0.1098 - val_recall_1: 0.3700 - val_F1_1: 0.1693
# Epoch 138/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1226 - accuracy: 0.9467 - precision_0: 0.9567 - recall_0: 0.9656 - F1_0: 0.9612 - precision_1: 0.9447 - recall_1: 0.9306 - F1_1: 0.9375 - val_loss: 2.5810 - val_accuracy: 0.3773 - val_precision_0: 0.7829 - val_recall_0: 0.3659 - val_F1_0: 0.4988 - val_precision_1: 0.1117 - val_recall_1: 0.4400 - val_F1_1: 0.1781
# Epoch 139/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.2300 - accuracy: 0.9086 - precision_0: 0.9288 - recall_0: 0.9059 - F1_0: 0.9169 - precision_1: 0.8617 - recall_1: 0.8907 - F1_1: 0.8756 - val_loss: 2.4959 - val_accuracy: 0.4264 - val_precision_0: 0.7947 - val_recall_0: 0.4348 - val_F1_0: 0.5621 - val_precision_1: 0.1086 - val_recall_1: 0.3800 - val_F1_1: 0.1689
# Epoch 140/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1254 - accuracy: 0.9509 - precision_0: 0.9482 - recall_0: 0.9652 - F1_0: 0.9566 - precision_1: 0.9420 - recall_1: 0.9139 - F1_1: 0.9277 - val_loss: 3.2815 - val_accuracy: 0.4724 - val_precision_0: 0.8077 - val_recall_0: 0.4946 - val_F1_0: 0.6135 - val_precision_1: 0.1115 - val_recall_1: 0.3500 - val_F1_1: 0.1691
# Epoch 141/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1243 - accuracy: 0.9489 - precision_0: 0.9556 - recall_0: 0.9618 - F1_0: 0.9587 - precision_1: 0.9394 - recall_1: 0.9297 - F1_1: 0.9345 - val_loss: 2.9441 - val_accuracy: 0.4755 - val_precision_0: 0.8144 - val_recall_0: 0.4928 - val_F1_0: 0.6140 - val_precision_1: 0.1195 - val_recall_1: 0.3800 - val_F1_1: 0.1818
# Epoch 142/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1349 - accuracy: 0.9444 - precision_0: 0.9397 - recall_0: 0.9525 - F1_0: 0.9460 - precision_1: 0.9252 - recall_1: 0.9049 - F1_1: 0.9148 - val_loss: 3.7504 - val_accuracy: 0.3696 - val_precision_0: 0.7925 - val_recall_0: 0.3460 - val_F1_0: 0.4817 - val_precision_1: 0.1217 - val_recall_1: 0.5000 - val_F1_1: 0.1957
# Epoch 143/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1799 - accuracy: 0.9301 - precision_0: 0.9380 - recall_0: 0.9414 - F1_0: 0.9395 - precision_1: 0.9090 - recall_1: 0.9014 - F1_1: 0.9050 - val_loss: 2.9166 - val_accuracy: 0.4985 - val_precision_0: 0.8319 - val_recall_0: 0.5109 - val_F1_0: 0.6330 - val_precision_1: 0.1374 - val_recall_1: 0.4300 - val_F1_1: 0.2082
# Epoch 144/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1189 - accuracy: 0.9538 - precision_0: 0.9544 - recall_0: 0.9689 - F1_0: 0.9616 - precision_1: 0.9471 - recall_1: 0.9219 - F1_1: 0.9343 - val_loss: 3.2106 - val_accuracy: 0.4617 - val_precision_0: 0.8190 - val_recall_0: 0.4674 - val_F1_0: 0.5952 - val_precision_1: 0.1276 - val_recall_1: 0.4300 - val_F1_1: 0.1968
# Epoch 145/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1340 - accuracy: 0.9457 - precision_0: 0.9508 - recall_0: 0.9625 - F1_0: 0.9566 - precision_1: 0.9409 - recall_1: 0.9230 - F1_1: 0.9318 - val_loss: 3.5066 - val_accuracy: 0.4110 - val_precision_0: 0.7857 - val_recall_0: 0.4185 - val_F1_0: 0.5461 - val_precision_1: 0.1034 - val_recall_1: 0.3700 - val_F1_1: 0.1616
# Epoch 146/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1101 - accuracy: 0.9567 - precision_0: 0.9606 - recall_0: 0.9700 - F1_0: 0.9652 - precision_1: 0.9508 - recall_1: 0.9370 - F1_1: 0.9437 - val_loss: 2.9231 - val_accuracy: 0.5245 - val_precision_0: 0.8343 - val_recall_0: 0.5471 - val_F1_0: 0.6608 - val_precision_1: 0.1379 - val_recall_1: 0.4000 - val_F1_1: 0.2051
# Epoch 147/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1136 - accuracy: 0.9535 - precision_0: 0.9591 - recall_0: 0.9711 - F1_0: 0.9651 - precision_1: 0.9533 - recall_1: 0.9343 - F1_1: 0.9436 - val_loss: 2.8265 - val_accuracy: 0.3880 - val_precision_0: 0.7703 - val_recall_0: 0.3949 - val_F1_0: 0.5222 - val_precision_1: 0.0949 - val_recall_1: 0.3500 - val_F1_1: 0.1493
# Epoch 148/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1495 - accuracy: 0.9434 - precision_0: 0.9558 - recall_0: 0.9743 - F1_0: 0.9650 - precision_1: 0.9573 - recall_1: 0.9270 - F1_1: 0.9419 - val_loss: 2.3769 - val_accuracy: 0.4571 - val_precision_0: 0.7812 - val_recall_0: 0.4982 - val_F1_0: 0.6084 - val_precision_1: 0.0767 - val_recall_1: 0.2300 - val_F1_1: 0.1150
# Epoch 149/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1358 - accuracy: 0.9411 - precision_0: 0.9436 - recall_0: 0.9607 - F1_0: 0.9520 - precision_1: 0.9380 - recall_1: 0.9131 - F1_1: 0.9252 - val_loss: 2.9215 - val_accuracy: 0.5138 - val_precision_0: 0.8367 - val_recall_0: 0.5290 - val_F1_0: 0.6482 - val_precision_1: 0.1419 - val_recall_1: 0.4300 - val_F1_1: 0.2134
# Epoch 150/150
# 97/97 [==============================] - 9s 91ms/step - loss: 0.1166 - accuracy: 0.9558 - precision_0: 0.9539 - recall_0: 0.9740 - F1_0: 0.9638 - precision_1: 0.9566 - recall_1: 0.9232 - F1_1: 0.9395 - val_loss: 3.5910 - val_accuracy: 0.4034 - val_precision_0: 0.7763 - val_recall_0: 0.4149 - val_F1_0: 0.5407 - val_precision_1: 0.0952 - val_recall_1: 0.3400 - val_F1_1: 0.1488

# %% [markdown]
# # results

# %% [markdown]
# ## loading test data

# %%
import glob
group1 = glob.glob('/A_LUAD/project/final_project/data/temp/two_test/group1/*.png')
group2 = glob.glob('/A_LUAD/project/final_project/data/temp/two_test/group2/*.png')

data = []
labels = []
filenames = []
for i in group1:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (300,300))
    image=np.array(image)
    data.append(image)
    labels.append(0)
    filenames.append(i)
for i in group2:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (300,300))
    image=np.array(image)
    data.append(image)
    labels.append(1)
    filenames.append(i)

x_test = np.array(data)
y_test = np.array(labels)

# %% [markdown]
# ## save eva results

# %%
import numpy as np
from sklearn.metrics import accuracy_score, confusion_matrix, roc_auc_score, roc_curve

# %%
name
# Out:
# '2-class-original1674758924'

# %%
######### evaluate model
testname = name + '_test'
results = model.evaluate(x_test, y_test)
# Out:
# 32/32 [==============================] - 2s 35ms/step - loss: 2.1562 - accuracy: 0.6196 - precision_0: 0.8044 - recall_0: 0.5258 - F1_0: 0.6274 - precision_1: 0.2223 - recall_1: 0.2980 - F1_1: 0.2501

# %%
test_path = '/A_LUAD/project/final_project/test_results'
## not sure
# test_name = name + '_pred.pickle'
# with open(os.path.join(test_path,test_name), 'wb') as file_pi:
#     pickle.dump(y_pred_lbls, file_pi)

######### visualization
y_pred=model.predict(x_test)
y_pred_lbls=np.argmax(y_pred,-1)

lbls=dict(map(lambda x: x.split('\t'),"""0 	<700 days
1 	>700 dayss""".split('\n')))
lbls={int(k):v for k,v in lbls.items()}

cm=ConfusionMatrixMetric(num_classes)
_=cm.update_state(y_test,y_pred)
fig, ax = plt.subplots(figsize=(6,4))
cm_matrix = cm.total_cm.numpy().astype(np.int32)
ax.matshow(cm_matrix, cmap=plt.cm.Blues)

for i in range(num_classes):
    for j in range(num_classes):
        c = cm_matrix[j,i]
        ax.text(i, j, str(c), va='center', ha='center')
plt.xticks(range(num_classes),['{} ({})'.format(lbls[i],'pred') for i in range(num_classes)])
plt.yticks(range(num_classes),['{} ({})'.format(lbls[i],'true') for i in range(num_classes)])
plt_name = name + '_loss'+str(round(results[0],2)) + '_acc'+str(round(results[1],2))+ '_p1_'+str(round(results[2],2))+ '_r1_'+str(round(results[3],2))+ '_f11_'+str(round(results[4],2))+ '_p2_'+str(round(results[5],2))+ '_r2_'+str(round(results[6],2))+ '_f12_'+str(round(results[7],2))+'_test.png'
plt.savefig(os.path.join(test_path, plt_name))
# plt.show()

# %%
auc = metrics.roc_auc_score(y_test, y_pred_lbls)
print(auc)
# Out:
# 0.6084637038714792

# %%
fpr, tpr, _ = metrics.roc_curve(y_test,  y_pred_lbls)
plt.plot(fpr,tpr,label="AUC="+str(auc))
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.legend(loc=4)
plt_name = name + '_Roc_'+ str(round(auc,2))+'_test.png'
plt.savefig(os.path.join(test_path, plt_name))
plt.show()

# %% [markdown]
# # case prediction

# %%
casepredict = dict()
for index, filename in enumerate(filenames):
  caseid = filename.split('\\')[-1].split('_')[0]
  # print(caseid)
  if caseid in casepredict:
    casepredict[caseid].append(y_pred_lbls[index])
    # print(casepredict)
  else:
    # print(caseid)
    casepredict[caseid] = [y_pred_lbls[index]]
# print(casepredict)
# len(casepredict)

# %%
case_pred_dict = dict()
for caseid in casepredict:
  counts = np.bincount(casepredict[caseid])
  #返回众数
  case_pred = np.argmax(counts)
  # print(case_pred)
  # case_pred_dict.append(caseid)
  case_pred_dict[caseid] = case_pred
# print(case_pred_dict)  
caseid_list = list(case_pred_dict.keys())

# %%
case_true_list = []
testdata = pd.read_csv('/A_LUAD/project/final_project/data/temp/two_test_cases.csv')
for caseid in caseid_list:
  case_truedf = testdata[testdata['case_submitter_id']==caseid]
  case_true = case_truedf['group'].values[0]-1
  case_true_list.append(case_true)
# print(case_true_list)

# %%
from sklearn.metrics import confusion_matrix
case_pred_list = list(case_pred_dict.values())
case_matrix = confusion_matrix(case_true_list, case_pred_list)
print(case_matrix)

lbls=dict(map(lambda x: x.split('\t'),"""0 	<700 days
1 	>700 dayss""".split('\n')))
lbls={int(k):v for k,v in lbls.items()}


fig, ax = plt.subplots(figsize=(6,4))
cm_matrix = case_matrix
ax.matshow(cm_matrix, cmap=plt.cm.Blues)

for i in range(num_classes):
    for j in range(num_classes):
        c = cm_matrix[j,i]
        ax.text(i, j, str(c), va='center', ha='center')
plt.xticks(range(num_classes),['{} ({})'.format(lbls[i],'pred') for i in range(num_classes)])
plt.yticks(range(num_classes),['{} ({})'.format(lbls[i],'true') for i in range(num_classes)])
plt_name = name + '_case_loss'+str(round(results[0],2)) + '_acc'+str(round(results[1],2))+'_test.png'
plt.savefig(os.path.join(test_path, plt_name))
# plt.show()
# Out:
# [[10 12]
#  [ 8 11]]

# %%
for index, case_pred in enumerate(case_pred_list):
  if case_pred != case_true_list[index]:
    print(caseid_list[index],case_true_list[index]+1)
# Out:
# TCGA-44-7659 1
# TCGA-44-A4SU 1
# TCGA-49-4490 1
# TCGA-49-4505 1
# TCGA-49-6745 1
# TCGA-50-5931 1
# TCGA-50-7109 1
# TCGA-55-8087 1
# TCGA-93-8067 1
# TCGA-95-7562 1
# TCGA-95-7944 1
# TCGA-95-A4VP 1
# TCGA-05-4245 2
# TCGA-05-4249 2
# TCGA-44-3918 2
# TCGA-44-7667 2
# TCGA-55-7724 2
# TCGA-55-8089 2
# TCGA-93-A4JN 2
# TCGA-97-7553 2

# %% [markdown]
# ## survival analysis for true value

# %%
clinical_data = pd.read_csv('/A_LUAD/project/final_project/data/temp/two_test_cases.csv')

# %%
clinical_data['died'] = np.where(clinical_data['vital_status'] == 'Dead', 1, 0)

# %%
clinical_data['os'] = clinical_data['survival_days']

# %%
clinical_data
# Out:
#    case_submitter_id vital_status  survival_days  survival_year  group  \
# 0       TCGA-97-A4M3        Alive            540              1      1
# 1       TCGA-50-7109         Dead            308              1      1
# 2       TCGA-49-6745        Alive            522              1      1
# 3       TCGA-44-7667        Alive           1097              3      2
# 4       TCGA-95-7944        Alive            377              1      1
# 5       TCGA-86-7711         Dead           1046              3      2
# 6       TCGA-97-A4M0        Alive            652              2      1
# 7       TCGA-55-7570        Alive            824              2      2
# 8       TCGA-L9-A443         Dead            193              1      1
# 9       TCGA-55-7724        Alive            705              2      2
# 10      TCGA-05-4415         Dead             91              0      1
# 11      TCGA-49-4490         Dead            385              1      1
# 12      TCGA-05-4249        Alive           1523              4      2
# 13      TCGA-95-A4VP        Alive            605              2      1
# 14      TCGA-55-7816         Dead            468              1      1
# 15      TCGA-95-7562         Dead             87              0      1
# 16      TCGA-55-7815        Alive            773              2      2
# 17      TCGA-44-7659        Alive            691              2      1
# 18      TCGA-55-8087        Alive            462              1      1
# 19      TCGA-49-4494         Dead           1081              3      2
# 20      TCGA-44-A479        Alive            486              1      1
# 21      TCGA-44-A4SU         Dead            409              1      1
# 22      TCGA-93-8067        Alive            186              1      1
# 23      TCGA-93-A4JN        Alive            718              2      2
# 24      TCGA-55-8089         Dead            702              2      2
# 25      TCGA-49-6744        Alive           1683              5      2
# 26      TCGA-44-3918        Alive           1036              3      2
# 27      TCGA-05-4422        Alive            365              1      1
# 28      TCGA-97-8552        Alive            626              2      1
# 29      TCGA-49-AARO        Alive           3759             10      2
# 30      TCGA-97-7553        Alive           1870              5      2
# 31      TCGA-05-4245        Alive            730              2      2
# 32      TCGA-49-4505         Dead            428              1      1
# 33      TCGA-97-A4LX        Alive            614              2      1
# 34      TCGA-50-5931         Dead            434              1      1
# 35      TCGA-97-A4M6        Alive            568              2      1
# 36      TCGA-38-4630         Dead           1073              3      2
# 37      TCGA-49-4506         Dead            999              3      2
# 38      TCGA-38-4629         Dead            864              2      2
# 39      TCGA-78-8640        Alive           7062             19      2
# 40      TCGA-55-7281        Alive            872              2      2
#
#    ajcc_pathologic_stage ajcc_staging_system_edition ajcc_pathologic_t  \
# 0               Stage IA                         7th               T1b
# 1               Stage IA                         7th                T1
# 2             Stage IIIA                         7th               T2a
# 3              Stage IIB                         6th                T3
# 4               Stage IA                         7th               T1a
# 5              Stage IIA                         7th               T2a
# 6               Stage IB                         7th               T2a
# 7               Stage IA                         7th               T1a
# 8               Stage IA                         7th               T1a
# 9               Stage IB                         7th               T2a
# 10            Stage IIIB                         6th                T4
# 11            Stage IIIA                         4th                T3
# 12              Stage IB                         6th                T2
# 13            Stage IIIA                         7th               T2b
# 14              Stage IV                         7th                TX
# 15             Stage IIA                         7th               T2a
# 16              Stage IB                         7th               T2a
# 17              Stage IA                         7th               T1b
# 18              Stage IB                         7th               T2a
# 19            Stage IIIA                         4th                T3
# 20              Stage IB                         7th                T2
# 21              Stage IA                         7th               T1a
# 22              Stage IB                         7th               T2a
# 23              Stage IV                         7th               T2a
# 24              Stage IA                         7th               T1a
# 25             Stage IIA                         7th               T2a
# 26              Stage IA                         6th                T1
# 27              Stage IB                         6th                T2
# 28               Stage I                         7th               T1a
# 29              Stage IA                         6th               T1a
# 30              Stage IA                         6th                T1
# 31            Stage IIIA                         6th                T2
# 32             Stage IIB                         4th                T2
# 33              Stage IB                         7th               T2a
# 34              Stage IB                         5th                T2
# 35              Stage IA                         7th               T1a
# 36              Stage IB                         6th                T2
# 37             Stage IIB                         4th                T2
# 38             Stage IIB                         '--                T3
# 39             Stage IIA                         6th                T1
# 40              Stage IA                         7th               T1b
#
#    ajcc_pathologic_m ajcc_pathologic_n  \
# 0                 M0                N0
# 1                 M0                N0
# 2                 M0                N2
# 3                 MX                N0
# 4                 M0                N0
# 5                 M0                N1
# 6                 M0                N0
# 7                 MX                N0
# 8                 MX                N0
# 9                 MX                N0
# 10                M0                N2
# 11                M0                N2
# 12                M0                N0
# 13                M0                N2
# 14                MX                NX
# 15                M0                N1
# 16                MX                N0
# 17                MX                N0
# 18                MX                N0
# 19                M0                N2
# 20                MX                N0
# 21                MX                N0
# 22                MX                N0
# 23               M1a                N0
# 24                M0                N0
# 25                MX                N1
# 26                M0                N0
# 27                M0                N0
# 28                MX                N0
# 29                MX                N0
# 30                MX                N0
# 31                M0                N2
# 32                M0                N1
# 33                M0                N0
# 34                M0                N0
# 35                M0                N0
# 36                M0                N0
# 37                M0                N1
# 38                M0                N0
# 39                M0                N1
# 40                M0                N0
#
#                               primary_diagnosis  died    os
# 0            Adenocarcinoma with mixed subtypes     0   540
# 1                           Adenocarcinoma, NOS     1   308
# 2                 Papillary adenocarcinoma, NOS     0   522
# 3                           Adenocarcinoma, NOS     0  1097
# 4                           Adenocarcinoma, NOS     0   377
# 5                           Adenocarcinoma, NOS     1  1046
# 6            Adenocarcinoma with mixed subtypes     0   652
# 7                           Adenocarcinoma, NOS     0   824
# 8                           Adenocarcinoma, NOS     1   193
# 9                           Adenocarcinoma, NOS     0   705
# 10           Adenocarcinoma with mixed subtypes     1    91
# 11                          Adenocarcinoma, NOS     1   385
# 12                          Adenocarcinoma, NOS     0  1523
# 13                        Acinar cell carcinoma     0   605
# 14                          Adenocarcinoma, NOS     1   468
# 15                          Adenocarcinoma, NOS     1    87
# 16                          Adenocarcinoma, NOS     0   773
# 17                          Adenocarcinoma, NOS     0   691
# 18                          Adenocarcinoma, NOS     0   462
# 19                          Adenocarcinoma, NOS     1  1081
# 20                          Adenocarcinoma, NOS     0   486
# 21                          Adenocarcinoma, NOS     1   409
# 22                          Adenocarcinoma, NOS     0   186
# 23                        Acinar cell carcinoma     0   718
# 24                          Adenocarcinoma, NOS     1   702
# 25           Adenocarcinoma with mixed subtypes     0  1683
# 26                          Adenocarcinoma, NOS     0  1036
# 27           Adenocarcinoma with mixed subtypes     0   365
# 28  Bronchiolo-alveolar carcinoma, non-mucinous     0   626
# 29                Papillary adenocarcinoma, NOS     0  3759
# 30  Bronchiolo-alveolar carcinoma, non-mucinous     0  1870
# 31                          Adenocarcinoma, NOS     0   730
# 32                          Adenocarcinoma, NOS     1   428
# 33           Adenocarcinoma with mixed subtypes     0   614
# 34                          Adenocarcinoma, NOS     1   434
# 35           Adenocarcinoma with mixed subtypes     0   568
# 36                Papillary adenocarcinoma, NOS     1  1073
# 37                          Adenocarcinoma, NOS     1   999
# 38                          Adenocarcinoma, NOS     1   864
# 39                          Adenocarcinoma, NOS     0  7062
# 40                          Adenocarcinoma, NOS     0   872

# %%
file_case_list = clinical_data['case_submitter_id'].tolist()

# %%
predicted_case = []
for i in file_case_list:
  predicted_case.append(case_pred_dict[i])

# %%
clinical_data['predicted_case'] = predicted_case

# %%
clinical_data
# Out:
#    case_submitter_id vital_status  survival_days  survival_year  group  \
# 0       TCGA-97-A4M3        Alive            540              1      1
# 1       TCGA-50-7109         Dead            308              1      1
# 2       TCGA-49-6745        Alive            522              1      1
# 3       TCGA-44-7667        Alive           1097              3      2
# 4       TCGA-95-7944        Alive            377              1      1
# 5       TCGA-86-7711         Dead           1046              3      2
# 6       TCGA-97-A4M0        Alive            652              2      1
# 7       TCGA-55-7570        Alive            824              2      2
# 8       TCGA-L9-A443         Dead            193              1      1
# 9       TCGA-55-7724        Alive            705              2      2
# 10      TCGA-05-4415         Dead             91              0      1
# 11      TCGA-49-4490         Dead            385              1      1
# 12      TCGA-05-4249        Alive           1523              4      2
# 13      TCGA-95-A4VP        Alive            605              2      1
# 14      TCGA-55-7816         Dead            468              1      1
# 15      TCGA-95-7562         Dead             87              0      1
# 16      TCGA-55-7815        Alive            773              2      2
# 17      TCGA-44-7659        Alive            691              2      1
# 18      TCGA-55-8087        Alive            462              1      1
# 19      TCGA-49-4494         Dead           1081              3      2
# 20      TCGA-44-A479        Alive            486              1      1
# 21      TCGA-44-A4SU         Dead            409              1      1
# 22      TCGA-93-8067        Alive            186              1      1
# 23      TCGA-93-A4JN        Alive            718              2      2
# 24      TCGA-55-8089         Dead            702              2      2
# 25      TCGA-49-6744        Alive           1683              5      2
# 26      TCGA-44-3918        Alive           1036              3      2
# 27      TCGA-05-4422        Alive            365              1      1
# 28      TCGA-97-8552        Alive            626              2      1
# 29      TCGA-49-AARO        Alive           3759             10      2
# 30      TCGA-97-7553        Alive           1870              5      2
# 31      TCGA-05-4245        Alive            730              2      2
# 32      TCGA-49-4505         Dead            428              1      1
# 33      TCGA-97-A4LX        Alive            614              2      1
# 34      TCGA-50-5931         Dead            434              1      1
# 35      TCGA-97-A4M6        Alive            568              2      1
# 36      TCGA-38-4630         Dead           1073              3      2
# 37      TCGA-49-4506         Dead            999              3      2
# 38      TCGA-38-4629         Dead            864              2      2
# 39      TCGA-78-8640        Alive           7062             19      2
# 40      TCGA-55-7281        Alive            872              2      2
#
#    ajcc_pathologic_stage ajcc_staging_system_edition ajcc_pathologic_t  \
# 0               Stage IA                         7th               T1b
# 1               Stage IA                         7th                T1
# 2             Stage IIIA                         7th               T2a
# 3              Stage IIB                         6th                T3
# 4               Stage IA                         7th               T1a
# 5              Stage IIA                         7th               T2a
# 6               Stage IB                         7th               T2a
# 7               Stage IA                         7th               T1a
# 8               Stage IA                         7th               T1a
# 9               Stage IB                         7th               T2a
# 10            Stage IIIB                         6th                T4
# 11            Stage IIIA                         4th                T3
# 12              Stage IB                         6th                T2
# 13            Stage IIIA                         7th               T2b
# 14              Stage IV                         7th                TX
# 15             Stage IIA                         7th               T2a
# 16              Stage IB                         7th               T2a
# 17              Stage IA                         7th               T1b
# 18              Stage IB                         7th               T2a
# 19            Stage IIIA                         4th                T3
# 20              Stage IB                         7th                T2
# 21              Stage IA                         7th               T1a
# 22              Stage IB                         7th               T2a
# 23              Stage IV                         7th               T2a
# 24              Stage IA                         7th               T1a
# 25             Stage IIA                         7th               T2a
# 26              Stage IA                         6th                T1
# 27              Stage IB                         6th                T2
# 28               Stage I                         7th               T1a
# 29              Stage IA                         6th               T1a
# 30              Stage IA                         6th                T1
# 31            Stage IIIA                         6th                T2
# 32             Stage IIB                         4th                T2
# 33              Stage IB                         7th               T2a
# 34              Stage IB                         5th                T2
# 35              Stage IA                         7th               T1a
# 36              Stage IB                         6th                T2
# 37             Stage IIB                         4th                T2
# 38             Stage IIB                         '--                T3
# 39             Stage IIA                         6th                T1
# 40              Stage IA                         7th               T1b
#
#    ajcc_pathologic_m ajcc_pathologic_n  \
# 0                 M0                N0
# 1                 M0                N0
# 2                 M0                N2
# 3                 MX                N0
# 4                 M0                N0
# 5                 M0                N1
# 6                 M0                N0
# 7                 MX                N0
# 8                 MX                N0
# 9                 MX                N0
# 10                M0                N2
# 11                M0                N2
# 12                M0                N0
# 13                M0                N2
# 14                MX                NX
# 15                M0                N1
# 16                MX                N0
# 17                MX                N0
# 18                MX                N0
# 19                M0                N2
# 20                MX                N0
# 21                MX                N0
# 22                MX                N0
# 23               M1a                N0
# 24                M0                N0
# 25                MX                N1
# 26                M0                N0
# 27                M0                N0
# 28                MX                N0
# 29                MX                N0
# 30                MX                N0
# 31                M0                N2
# 32                M0                N1
# 33                M0                N0
# 34                M0                N0
# 35                M0                N0
# 36                M0                N0
# 37                M0                N1
# 38                M0                N0
# 39                M0                N1
# 40                M0                N0
#
#                               primary_diagnosis  died    os  predicted_case
# 0            Adenocarcinoma with mixed subtypes     0   540               0
# 1                           Adenocarcinoma, NOS     1   308               1
# 2                 Papillary adenocarcinoma, NOS     0   522               1
# 3                           Adenocarcinoma, NOS     0  1097               0
# 4                           Adenocarcinoma, NOS     0   377               1
# 5                           Adenocarcinoma, NOS     1  1046               1
# 6            Adenocarcinoma with mixed subtypes     0   652               0
# 7                           Adenocarcinoma, NOS     0   824               1
# 8                           Adenocarcinoma, NOS     1   193               0
# 9                           Adenocarcinoma, NOS     0   705               0
# 10           Adenocarcinoma with mixed subtypes     1    91               0
# 11                          Adenocarcinoma, NOS     1   385               1
# 12                          Adenocarcinoma, NOS     0  1523               0
# 13                        Acinar cell carcinoma     0   605               1
# 14                          Adenocarcinoma, NOS     1   468               0
# 15                          Adenocarcinoma, NOS     1    87               1
# 16                          Adenocarcinoma, NOS     0   773               1
# 17                          Adenocarcinoma, NOS     0   691               1
# 18                          Adenocarcinoma, NOS     0   462               1
# 19                          Adenocarcinoma, NOS     1  1081               1
# 20                          Adenocarcinoma, NOS     0   486               0
# 21                          Adenocarcinoma, NOS     1   409               1
# 22                          Adenocarcinoma, NOS     0   186               1
# 23                        Acinar cell carcinoma     0   718               0
# 24                          Adenocarcinoma, NOS     1   702               0
# 25           Adenocarcinoma with mixed subtypes     0  1683               1
# 26                          Adenocarcinoma, NOS     0  1036               0
# 27           Adenocarcinoma with mixed subtypes     0   365               0
# 28  Bronchiolo-alveolar carcinoma, non-mucinous     0   626               0
# 29                Papillary adenocarcinoma, NOS     0  3759               1
# 30  Bronchiolo-alveolar carcinoma, non-mucinous     0  1870               0
# 31                          Adenocarcinoma, NOS     0   730               0
# 32                          Adenocarcinoma, NOS     1   428               1
# 33           Adenocarcinoma with mixed subtypes     0   614               0
# 34                          Adenocarcinoma, NOS     1   434               1
# 35           Adenocarcinoma with mixed subtypes     0   568               0
# 36                Papillary adenocarcinoma, NOS     1  1073               1
# 37                          Adenocarcinoma, NOS     1   999               1
# 38                          Adenocarcinoma, NOS     1   864               1
# 39                          Adenocarcinoma, NOS     0  7062               1
# 40                          Adenocarcinoma, NOS     0   872               1

# %%
save_path = 'two_class_survival' + name+ '.csv'
clinical_data.to_csv(os.path.join('/A_LUAD/project/final_project/test_results', save_path),index=False)
