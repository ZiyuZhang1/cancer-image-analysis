# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pandas as pd
import glob
import os
from tensorflow.keras.callbacks import TensorBoard
import time
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# # set parameters

# %%
batch_size = 32
epoch = 150
img_height = 300
img_width = 300
root = '/A_LUAD/project/final_project'
name = '2-class-downsample{}'.format(int(time.time()))
tensorboard = TensorBoard(log_dir='/A_LUAD/project/final_project/logs/{}'.format(name))

# %% [markdown]
# # load data

# %%
train_dir = '/A_LUAD/project/final_project/data/temp/down_train'
val_dir = '/A_LUAD/project/final_project/data/temp/down_val'

train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  train_dir,
  image_size=(img_height, img_width),
  batch_size=batch_size)


val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  val_dir,
  image_size=(img_height, img_width),
  batch_size=batch_size)

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
# Out:
# Found 1796 files belonging to 2 classes.
# Found 477 files belonging to 2 classes.

# %% [markdown]
# # build model

# %%
class ConfusionMatrixMetric(tf.keras.metrics.Metric):
    """
    A custom Keras metric to compute the running average of the confusion matrix
    """
    def __init__(self, num_classes, **kwargs):
        super(ConfusionMatrixMetric,self).__init__(name='confusion_matrix_metric',**kwargs) # handles base args (e.g., dtype)
        self.num_classes=num_classes
        self.total_cm = self.add_weight("total", shape=(num_classes,num_classes), initializer="zeros")
        
    def reset_state(self):
        for s in self.variables:
            s.assign(tf.zeros(shape=s.shape))
            
    def update_state(self, y_true, y_pred,sample_weight=None):
        self.total_cm.assign_add(self.confusion_matrix(y_true,y_pred))
        return self.total_cm
        
    def result(self):
        return self.process_confusion_matrix()
    
    def confusion_matrix(self,y_true, y_pred):
        """
        Make a confusion matrix
        """
        y_pred=tf.argmax(y_pred,1)
        cm=tf.math.confusion_matrix(y_true,y_pred,dtype=tf.float32,num_classes=self.num_classes)
        return cm
    
    def process_confusion_matrix(self):
        "returns precision, recall and f1 along with overall accuracy"
        cm=self.total_cm
        diag_part=tf.linalg.diag_part(cm)
        precision=diag_part/(tf.reduce_sum(cm,0)+tf.constant(1e-15))
        recall=diag_part/(tf.reduce_sum(cm,1)+tf.constant(1e-15))
        f1=2*precision*recall/(precision+recall+tf.constant(1e-15))
        return precision,recall,f1
    
    def fill_output(self,output):
        results=self.result()
        for i in range(self.num_classes):
            output['precision_{}'.format(i)]=results[0][i]
            output['recall_{}'.format(i)]=results[1][i]
            output['F1_{}'.format(i)]=results[2][i]
    # def get_config(self):
    #     config = super(ConfusionMatrixMetric, self).get_config()
    #     config.update({"num_classes": self.num_classes,"total_cm": self.total_cm})
    #     return config
    
class MySequential(keras.Sequential):
    
    def train_step(self, data):
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.

        x, y = data

        with tf.GradientTape() as tape:
            y_pred = self(x, training=True)  # Forward pass
            # Compute the loss value.
            # The loss function is configured in `compile()`.
            loss = self.compiled_loss(
                y,
                y_pred,
                regularization_losses=self.losses,
            )

        # Compute gradients
        trainable_vars = self.trainable_variables
        gradients = tape.gradient(loss, trainable_vars)

        # Update weights
        self.optimizer.apply_gradients(zip(gradients, trainable_vars))
        self.compiled_metrics.update_state(y, y_pred)
        output={m.name: m.result() for m in self.metrics[:-1]}
        if 'confusion_matrix_metric' in self.metrics_names:
            self.metrics[-1].fill_output(output)
        return output
        
        
    def test_step(self, data):
        # Unpack the data. Its structure depends on your model and
        # on what you pass to `fit()`.

        x, y = data

        y_pred = self(x, training=False)  # Forward pass
        # Compute the loss value.
        # The loss function is configured in `compile()`.
        loss = self.compiled_loss(
            y,
            y_pred,
            regularization_losses=self.losses,
        )

        self.compiled_metrics.update_state(y, y_pred)
        output={m.name: m.result() for m in self.metrics[:-1]}
        if 'confusion_matrix_metric' in self.metrics_names:
            self.metrics[-1].fill_output(output)    
        return output

# %% [markdown]
# ## with data augmentatiom

# %%
data_augmentation = keras.Sequential(
  [
    keras.layers.experimental.preprocessing.RandomFlip("horizontal",
                                                 input_shape=(img_height,
                                                              img_width,
                                                              3)),
    keras.layers.experimental.preprocessing.RandomRotation(0.1),
    keras.layers.experimental.preprocessing.RandomZoom(0.1),
  ]
)

####### model
num_classes = 2
# Dropout
model = MySequential([
  data_augmentation,
  keras.layers.experimental.preprocessing.Rescaling(1./300),
  keras.layers.Conv2D(16, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(32, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Conv2D(64, 3, padding='same', activation='relu'),
  keras.layers.MaxPooling2D(),
  keras.layers.Dropout(0.2),
  keras.layers.GlobalAveragePooling2D(),
  keras.layers.Dense(64, activation='relu'),
  keras.layers.Dense(64, activation='relu'),
  keras.layers.Dense(num_classes)
])
loss=keras.losses.SparseCategoricalCrossentropy(from_logits=True)
optimizer=keras.optimizers.Adam()
model.compile(loss=loss,optimizer=optimizer,metrics=['accuracy',ConfusionMatrixMetric(2)])

# %% [markdown]
# # train

# %%
# es=keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=100)
history=model.fit(train_ds,validation_data=val_ds,epochs=epoch, verbose=1, callbacks=[tensorboard])
# Out:
# Epoch 1/150
# 57/57 [==============================] - 10s 124ms/step - loss: 0.6941 - accuracy: 0.5356 - precision_0: 0.5380 - recall_0: 0.9690 - F1_0: 0.6917 - precision_1: 0.2937 - recall_1: 0.0202 - F1_1: 0.0373 - val_loss: 0.6555 - val_accuracy: 0.7904 - val_precision_0: 0.7904 - val_recall_0: 1.0000 - val_F1_0: 0.8829 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_F1_1: 0.0000e+00
# Epoch 2/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.6885 - accuracy: 0.5401 - precision_0: 0.5501 - recall_0: 1.0000 - F1_0: 0.7097 - precision_1: 0.0000e+00 - recall_1: 0.0000e+00 - F1_1: 0.0000e+00 - val_loss: 0.6397 - val_accuracy: 0.7904 - val_precision_0: 0.7904 - val_recall_0: 1.0000 - val_F1_0: 0.8829 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_F1_1: 0.0000e+00
# Epoch 3/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.6822 - accuracy: 0.5585 - precision_0: 0.5414 - recall_0: 0.9587 - F1_0: 0.6915 - precision_1: 0.4484 - recall_1: 0.0697 - F1_1: 0.1183 - val_loss: 0.5837 - val_accuracy: 0.7966 - val_precision_0: 0.7966 - val_recall_0: 0.9973 - val_F1_0: 0.8857 - val_precision_1: 0.8000 - val_recall_1: 0.0400 - val_F1_1: 0.0762
# Epoch 4/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.6799 - accuracy: 0.5646 - precision_0: 0.5922 - recall_0: 0.6989 - F1_0: 0.6370 - precision_1: 0.5356 - recall_1: 0.4259 - F1_1: 0.4635 - val_loss: 0.6417 - val_accuracy: 0.7568 - val_precision_0: 0.7831 - val_recall_0: 0.9576 - val_F1_0: 0.8616 - val_precision_1: 0.0000e+00 - val_recall_1: 0.0000e+00 - val_F1_1: 0.0000e+00
# Epoch 5/150
# 57/57 [==============================] - 6s 111ms/step - loss: 0.6617 - accuracy: 0.5735 - precision_0: 0.5733 - recall_0: 0.6902 - F1_0: 0.6243 - precision_1: 0.5071 - recall_1: 0.3928 - F1_1: 0.4401 - val_loss: 0.6382 - val_accuracy: 0.6059 - val_precision_0: 0.7561 - val_recall_0: 0.7401 - val_F1_0: 0.7480 - val_precision_1: 0.0926 - val_recall_1: 0.1000 - val_F1_1: 0.0962
# Epoch 6/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.6408 - accuracy: 0.6052 - precision_0: 0.6203 - recall_0: 0.5748 - F1_0: 0.5955 - precision_1: 0.5295 - recall_1: 0.5760 - F1_1: 0.5507 - val_loss: 0.6797 - val_accuracy: 0.4549 - val_precision_0: 0.6957 - val_recall_0: 0.5517 - val_F1_0: 0.6154 - val_precision_1: 0.0506 - val_recall_1: 0.0900 - val_F1_1: 0.0647
# Epoch 7/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.6326 - accuracy: 0.6147 - precision_0: 0.6717 - recall_0: 0.5678 - F1_0: 0.6148 - precision_1: 0.5763 - recall_1: 0.6791 - F1_1: 0.6229 - val_loss: 0.6831 - val_accuracy: 0.4130 - val_precision_0: 0.6932 - val_recall_0: 0.4615 - val_F1_0: 0.5541 - val_precision_1: 0.1018 - val_recall_1: 0.2300 - val_F1_1: 0.1411
# Epoch 8/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.6150 - accuracy: 0.6264 - precision_0: 0.7174 - recall_0: 0.5665 - F1_0: 0.6326 - precision_1: 0.5750 - recall_1: 0.7237 - F1_1: 0.6405 - val_loss: 0.6962 - val_accuracy: 0.2893 - val_precision_0: 0.6267 - val_recall_0: 0.2493 - val_F1_0: 0.3567 - val_precision_1: 0.1346 - val_recall_1: 0.4400 - val_F1_1: 0.2061
# Epoch 9/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.6127 - accuracy: 0.6192 - precision_0: 0.7019 - recall_0: 0.5326 - F1_0: 0.6022 - precision_1: 0.5645 - recall_1: 0.7233 - F1_1: 0.6327 - val_loss: 0.7366 - val_accuracy: 0.4591 - val_precision_0: 0.7297 - val_recall_0: 0.5013 - val_F1_0: 0.5943 - val_precision_1: 0.1376 - val_recall_1: 0.3000 - val_F1_1: 0.1887
# Epoch 10/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.6112 - accuracy: 0.6297 - precision_0: 0.6923 - recall_0: 0.5737 - F1_0: 0.6251 - precision_1: 0.5821 - recall_1: 0.6957 - F1_1: 0.6326 - val_loss: 0.6808 - val_accuracy: 0.4340 - val_precision_0: 0.7082 - val_recall_0: 0.4828 - val_F1_0: 0.5741 - val_precision_1: 0.1136 - val_recall_1: 0.2500 - val_F1_1: 0.1562
# Epoch 11/150
# 57/57 [==============================] - 6s 101ms/step - loss: 0.6083 - accuracy: 0.6236 - precision_0: 0.7103 - recall_0: 0.4938 - F1_0: 0.5817 - precision_1: 0.5715 - recall_1: 0.7687 - F1_1: 0.6552 - val_loss: 0.6662 - val_accuracy: 0.7191 - val_precision_0: 0.7832 - val_recall_0: 0.8912 - val_F1_0: 0.8337 - val_precision_1: 0.1458 - val_recall_1: 0.0700 - val_F1_1: 0.0946
# Epoch 12/150
# 57/57 [==============================] - 6s 100ms/step - loss: 0.6143 - accuracy: 0.6186 - precision_0: 0.6452 - recall_0: 0.6244 - F1_0: 0.6286 - precision_1: 0.5818 - recall_1: 0.5883 - F1_1: 0.5713 - val_loss: 0.7147 - val_accuracy: 0.4067 - val_precision_0: 0.7026 - val_recall_0: 0.4324 - val_F1_0: 0.5353 - val_precision_1: 0.1265 - val_recall_1: 0.3100 - val_F1_1: 0.1797
# Epoch 13/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5945 - accuracy: 0.6342 - precision_0: 0.7307 - recall_0: 0.4983 - F1_0: 0.5910 - precision_1: 0.6079 - recall_1: 0.8057 - F1_1: 0.6925 - val_loss: 0.6498 - val_accuracy: 0.5849 - val_precision_0: 0.7564 - val_recall_0: 0.7003 - val_F1_0: 0.7273 - val_precision_1: 0.1172 - val_recall_1: 0.1500 - val_F1_1: 0.1316
# Epoch 14/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.6004 - accuracy: 0.6275 - precision_0: 0.7310 - recall_0: 0.5325 - F1_0: 0.6145 - precision_1: 0.5943 - recall_1: 0.7774 - F1_1: 0.6725 - val_loss: 0.6746 - val_accuracy: 0.5597 - val_precision_0: 0.7554 - val_recall_0: 0.6552 - val_F1_0: 0.7017 - val_precision_1: 0.1333 - val_recall_1: 0.2000 - val_F1_1: 0.1600
# Epoch 15/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.6086 - accuracy: 0.6320 - precision_0: 0.6792 - recall_0: 0.5752 - F1_0: 0.6216 - precision_1: 0.5736 - recall_1: 0.6755 - F1_1: 0.6193 - val_loss: 0.6751 - val_accuracy: 0.4486 - val_precision_0: 0.7127 - val_recall_0: 0.5066 - val_F1_0: 0.5922 - val_precision_1: 0.1100 - val_recall_1: 0.2300 - val_F1_1: 0.1489
# Epoch 16/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5941 - accuracy: 0.6570 - precision_0: 0.7547 - recall_0: 0.5384 - F1_0: 0.6281 - precision_1: 0.6042 - recall_1: 0.8012 - F1_1: 0.6886 - val_loss: 0.6654 - val_accuracy: 0.5786 - val_precision_0: 0.7667 - val_recall_0: 0.6711 - val_F1_0: 0.7157 - val_precision_1: 0.1565 - val_recall_1: 0.2300 - val_F1_1: 0.1862
# Epoch 17/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5950 - accuracy: 0.6314 - precision_0: 0.7156 - recall_0: 0.5502 - F1_0: 0.6213 - precision_1: 0.5767 - recall_1: 0.7359 - F1_1: 0.6460 - val_loss: 0.7023 - val_accuracy: 0.5346 - val_precision_0: 0.7645 - val_recall_0: 0.5942 - val_F1_0: 0.6687 - val_precision_1: 0.1685 - val_recall_1: 0.3100 - val_F1_1: 0.2183
# Epoch 18/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5921 - accuracy: 0.6487 - precision_0: 0.6823 - recall_0: 0.7238 - F1_0: 0.6980 - precision_1: 0.6192 - recall_1: 0.5636 - F1_1: 0.5829 - val_loss: 0.6663 - val_accuracy: 0.4885 - val_precision_0: 0.7254 - val_recall_0: 0.5676 - val_F1_0: 0.6369 - val_precision_1: 0.1044 - val_recall_1: 0.1900 - val_F1_1: 0.1348
# Epoch 19/150
# 57/57 [==============================] - 6s 107ms/step - loss: 0.5940 - accuracy: 0.6409 - precision_0: 0.7358 - recall_0: 0.5477 - F1_0: 0.6273 - precision_1: 0.5799 - recall_1: 0.7592 - F1_1: 0.6572 - val_loss: 0.7007 - val_accuracy: 0.3229 - val_precision_0: 0.6500 - val_recall_0: 0.3103 - val_F1_0: 0.4201 - val_precision_1: 0.1246 - val_recall_1: 0.3700 - val_F1_1: 0.1864
# Epoch 20/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5978 - accuracy: 0.6359 - precision_0: 0.6939 - recall_0: 0.5815 - F1_0: 0.6294 - precision_1: 0.5957 - recall_1: 0.7001 - F1_1: 0.6416 - val_loss: 0.7402 - val_accuracy: 0.4340 - val_precision_0: 0.7184 - val_recall_0: 0.4668 - val_F1_0: 0.5659 - val_precision_1: 0.1336 - val_recall_1: 0.3100 - val_F1_1: 0.1867
# Epoch 21/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5918 - accuracy: 0.6398 - precision_0: 0.7394 - recall_0: 0.5491 - F1_0: 0.6277 - precision_1: 0.6096 - recall_1: 0.7827 - F1_1: 0.6838 - val_loss: 0.7992 - val_accuracy: 0.3459 - val_precision_0: 0.6970 - val_recall_0: 0.3050 - val_F1_0: 0.4244 - val_precision_1: 0.1603 - val_recall_1: 0.5000 - val_F1_1: 0.2427
# Epoch 22/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5922 - accuracy: 0.6476 - precision_0: 0.6915 - recall_0: 0.6839 - F1_0: 0.6794 - precision_1: 0.6153 - recall_1: 0.6081 - F1_1: 0.6044 - val_loss: 0.6878 - val_accuracy: 0.4675 - val_precision_0: 0.7253 - val_recall_0: 0.5252 - val_F1_0: 0.6092 - val_precision_1: 0.1225 - val_recall_1: 0.2500 - val_F1_1: 0.1645
# Epoch 23/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5839 - accuracy: 0.6609 - precision_0: 0.7624 - recall_0: 0.5437 - F1_0: 0.6337 - precision_1: 0.6154 - recall_1: 0.8101 - F1_1: 0.6990 - val_loss: 0.6771 - val_accuracy: 0.4298 - val_precision_0: 0.7075 - val_recall_0: 0.4748 - val_F1_0: 0.5683 - val_precision_1: 0.1161 - val_recall_1: 0.2600 - val_F1_1: 0.1605
# Epoch 24/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5823 - accuracy: 0.6570 - precision_0: 0.7074 - recall_0: 0.6041 - F1_0: 0.6472 - precision_1: 0.5946 - recall_1: 0.6936 - F1_1: 0.6373 - val_loss: 0.7311 - val_accuracy: 0.4696 - val_precision_0: 0.7403 - val_recall_0: 0.5066 - val_F1_0: 0.6016 - val_precision_1: 0.1507 - val_recall_1: 0.3300 - val_F1_1: 0.2069
# Epoch 25/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5798 - accuracy: 0.6670 - precision_0: 0.7273 - recall_0: 0.6128 - F1_0: 0.6644 - precision_1: 0.6129 - recall_1: 0.7266 - F1_1: 0.6643 - val_loss: 0.6910 - val_accuracy: 0.6059 - val_precision_0: 0.7855 - val_recall_0: 0.6897 - val_F1_0: 0.7345 - val_precision_1: 0.1986 - val_recall_1: 0.2900 - val_F1_1: 0.2358
# Epoch 26/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.5844 - accuracy: 0.6826 - precision_0: 0.7514 - recall_0: 0.6213 - F1_0: 0.6784 - precision_1: 0.6348 - recall_1: 0.7588 - F1_1: 0.6897 - val_loss: 0.7047 - val_accuracy: 0.4235 - val_precision_0: 0.7217 - val_recall_0: 0.4403 - val_F1_0: 0.5470 - val_precision_1: 0.1457 - val_recall_1: 0.3600 - val_F1_1: 0.2075
# Epoch 27/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5794 - accuracy: 0.6693 - precision_0: 0.7209 - recall_0: 0.7036 - F1_0: 0.7095 - precision_1: 0.6329 - recall_1: 0.6491 - F1_1: 0.6381 - val_loss: 0.7815 - val_accuracy: 0.3187 - val_precision_0: 0.6429 - val_recall_0: 0.3103 - val_F1_0: 0.4186 - val_precision_1: 0.1186 - val_recall_1: 0.3500 - val_F1_1: 0.1772
# Epoch 28/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5826 - accuracy: 0.6526 - precision_0: 0.6933 - recall_0: 0.6122 - F1_0: 0.6433 - precision_1: 0.5849 - recall_1: 0.6624 - F1_1: 0.6158 - val_loss: 0.6722 - val_accuracy: 0.5409 - val_precision_0: 0.7500 - val_recall_0: 0.6286 - val_F1_0: 0.6840 - val_precision_1: 0.1304 - val_recall_1: 0.2100 - val_F1_1: 0.1609
# Epoch 29/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5688 - accuracy: 0.6938 - precision_0: 0.7270 - recall_0: 0.6953 - F1_0: 0.7103 - precision_1: 0.6256 - recall_1: 0.6608 - F1_1: 0.6419 - val_loss: 0.7488 - val_accuracy: 0.3878 - val_precision_0: 0.7136 - val_recall_0: 0.3767 - val_F1_0: 0.4931 - val_precision_1: 0.1547 - val_recall_1: 0.4300 - val_F1_1: 0.2275
# Epoch 30/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5719 - accuracy: 0.6949 - precision_0: 0.7578 - recall_0: 0.6447 - F1_0: 0.6933 - precision_1: 0.6457 - recall_1: 0.7514 - F1_1: 0.6927 - val_loss: 0.7387 - val_accuracy: 0.4319 - val_precision_0: 0.7409 - val_recall_0: 0.4324 - val_F1_0: 0.5461 - val_precision_1: 0.1673 - val_recall_1: 0.4300 - val_F1_1: 0.2409
# Epoch 31/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.5642 - accuracy: 0.6815 - precision_0: 0.7439 - recall_0: 0.5965 - F1_0: 0.6596 - precision_1: 0.6225 - recall_1: 0.7605 - F1_1: 0.6833 - val_loss: 0.6954 - val_accuracy: 0.6122 - val_precision_0: 0.7892 - val_recall_0: 0.6950 - val_F1_0: 0.7391 - val_precision_1: 0.2069 - val_recall_1: 0.3000 - val_F1_1: 0.2449
# Epoch 32/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5635 - accuracy: 0.6854 - precision_0: 0.7069 - recall_0: 0.7251 - F1_0: 0.7146 - precision_1: 0.6633 - recall_1: 0.6351 - F1_1: 0.6459 - val_loss: 0.7315 - val_accuracy: 0.5493 - val_precision_0: 0.7736 - val_recall_0: 0.6074 - val_F1_0: 0.6805 - val_precision_1: 0.1823 - val_recall_1: 0.3300 - val_F1_1: 0.2349
# Epoch 33/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5507 - accuracy: 0.7199 - precision_0: 0.7606 - recall_0: 0.7435 - F1_0: 0.7515 - precision_1: 0.7108 - recall_1: 0.7294 - F1_1: 0.7195 - val_loss: 0.7822 - val_accuracy: 0.5577 - val_precision_0: 0.7823 - val_recall_0: 0.6101 - val_F1_0: 0.6855 - val_precision_1: 0.1967 - val_recall_1: 0.3600 - val_F1_1: 0.2544
# Epoch 34/150
# 57/57 [==============================] - 6s 107ms/step - loss: 0.5510 - accuracy: 0.7082 - precision_0: 0.7400 - recall_0: 0.7587 - F1_0: 0.7479 - precision_1: 0.6954 - recall_1: 0.6653 - F1_1: 0.6765 - val_loss: 0.7259 - val_accuracy: 0.5367 - val_precision_0: 0.7671 - val_recall_0: 0.5942 - val_F1_0: 0.6697 - val_precision_1: 0.1730 - val_recall_1: 0.3200 - val_F1_1: 0.2246
# Epoch 35/150
# 57/57 [==============================] - 6s 100ms/step - loss: 0.5477 - accuracy: 0.7177 - precision_0: 0.7391 - recall_0: 0.7480 - F1_0: 0.7418 - precision_1: 0.6978 - recall_1: 0.6765 - F1_1: 0.6823 - val_loss: 0.7144 - val_accuracy: 0.5073 - val_precision_0: 0.7649 - val_recall_0: 0.5438 - val_F1_0: 0.6357 - val_precision_1: 0.1770 - val_recall_1: 0.3700 - val_F1_1: 0.2395
# Epoch 36/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5328 - accuracy: 0.7333 - precision_0: 0.7533 - recall_0: 0.7406 - F1_0: 0.7465 - precision_1: 0.7087 - recall_1: 0.7217 - F1_1: 0.7147 - val_loss: 0.7025 - val_accuracy: 0.5283 - val_precision_0: 0.7794 - val_recall_0: 0.5623 - val_F1_0: 0.6533 - val_precision_1: 0.1951 - val_recall_1: 0.4000 - val_F1_1: 0.2623
# Epoch 37/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5497 - accuracy: 0.7166 - precision_0: 0.7828 - recall_0: 0.7311 - F1_0: 0.7559 - precision_1: 0.7096 - recall_1: 0.7642 - F1_1: 0.7356 - val_loss: 0.7908 - val_accuracy: 0.4025 - val_precision_0: 0.7323 - val_recall_0: 0.3846 - val_F1_0: 0.5043 - val_precision_1: 0.1685 - val_recall_1: 0.4700 - val_F1_1: 0.2480
# Epoch 38/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5472 - accuracy: 0.7082 - precision_0: 0.7393 - recall_0: 0.6591 - F1_0: 0.6946 - precision_1: 0.6306 - recall_1: 0.7111 - F1_1: 0.6667 - val_loss: 0.7022 - val_accuracy: 0.5618 - val_precision_0: 0.7625 - val_recall_0: 0.6472 - val_F1_0: 0.7001 - val_precision_1: 0.1529 - val_recall_1: 0.2400 - val_F1_1: 0.1868
# Epoch 39/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5347 - accuracy: 0.7272 - precision_0: 0.7702 - recall_0: 0.7064 - F1_0: 0.7359 - precision_1: 0.6921 - recall_1: 0.7550 - F1_1: 0.7210 - val_loss: 0.7030 - val_accuracy: 0.5996 - val_precision_0: 0.7906 - val_recall_0: 0.6711 - val_F1_0: 0.7260 - val_precision_1: 0.2102 - val_recall_1: 0.3300 - val_F1_1: 0.2568
# Epoch 40/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5322 - accuracy: 0.7378 - precision_0: 0.7456 - recall_0: 0.7450 - F1_0: 0.7441 - precision_1: 0.6896 - recall_1: 0.6888 - F1_1: 0.6870 - val_loss: 0.9328 - val_accuracy: 0.4088 - val_precision_0: 0.7387 - val_recall_0: 0.3899 - val_F1_0: 0.5104 - val_precision_1: 0.1727 - val_recall_1: 0.4800 - val_F1_1: 0.2540
# Epoch 41/150
# 57/57 [==============================] - 6s 107ms/step - loss: 0.5387 - accuracy: 0.7355 - precision_0: 0.7811 - recall_0: 0.6997 - F1_0: 0.7364 - precision_1: 0.6883 - recall_1: 0.7678 - F1_1: 0.7248 - val_loss: 0.7094 - val_accuracy: 0.5031 - val_precision_0: 0.7672 - val_recall_0: 0.5332 - val_F1_0: 0.6291 - val_precision_1: 0.1814 - val_recall_1: 0.3900 - val_F1_1: 0.2476
# Epoch 42/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5199 - accuracy: 0.7378 - precision_0: 0.7722 - recall_0: 0.7098 - F1_0: 0.7395 - precision_1: 0.6838 - recall_1: 0.7499 - F1_1: 0.7151 - val_loss: 0.7626 - val_accuracy: 0.4906 - val_precision_0: 0.7659 - val_recall_0: 0.5119 - val_F1_0: 0.6137 - val_precision_1: 0.1822 - val_recall_1: 0.4100 - val_F1_1: 0.2523
# Epoch 43/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.5288 - accuracy: 0.7244 - precision_0: 0.7443 - recall_0: 0.7025 - F1_0: 0.7223 - precision_1: 0.6814 - recall_1: 0.7235 - F1_1: 0.7012 - val_loss: 0.6894 - val_accuracy: 0.5639 - val_precision_0: 0.7538 - val_recall_0: 0.6658 - val_F1_0: 0.7070 - val_precision_1: 0.1250 - val_recall_1: 0.1800 - val_F1_1: 0.1475
# Epoch 44/150
# 57/57 [==============================] - 5s 94ms/step - loss: 0.5253 - accuracy: 0.7322 - precision_0: 0.7571 - recall_0: 0.7169 - F1_0: 0.7357 - precision_1: 0.6758 - recall_1: 0.7165 - F1_1: 0.6945 - val_loss: 0.7682 - val_accuracy: 0.4948 - val_precision_0: 0.7576 - val_recall_0: 0.5305 - val_F1_0: 0.6240 - val_precision_1: 0.1690 - val_recall_1: 0.3600 - val_F1_1: 0.2300
# Epoch 45/150
# 57/57 [==============================] - 6s 101ms/step - loss: 0.5158 - accuracy: 0.7422 - precision_0: 0.7625 - recall_0: 0.7160 - F1_0: 0.7377 - precision_1: 0.7024 - recall_1: 0.7501 - F1_1: 0.7246 - val_loss: 0.7896 - val_accuracy: 0.4759 - val_precision_0: 0.7702 - val_recall_0: 0.4801 - val_F1_0: 0.5915 - val_precision_1: 0.1901 - val_recall_1: 0.4600 - val_F1_1: 0.2690
# Epoch 46/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5097 - accuracy: 0.7450 - precision_0: 0.7884 - recall_0: 0.6998 - F1_0: 0.7412 - precision_1: 0.7120 - recall_1: 0.7979 - F1_1: 0.7523 - val_loss: 0.7299 - val_accuracy: 0.5031 - val_precision_0: 0.7672 - val_recall_0: 0.5332 - val_F1_0: 0.6291 - val_precision_1: 0.1814 - val_recall_1: 0.3900 - val_F1_1: 0.2476
# Epoch 47/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5069 - accuracy: 0.7478 - precision_0: 0.7790 - recall_0: 0.7142 - F1_0: 0.7450 - precision_1: 0.7082 - recall_1: 0.7735 - F1_1: 0.7392 - val_loss: 0.9042 - val_accuracy: 0.3480 - val_precision_0: 0.6919 - val_recall_0: 0.3156 - val_F1_0: 0.4335 - val_precision_1: 0.1541 - val_recall_1: 0.4700 - val_F1_1: 0.2321
# Epoch 48/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5074 - accuracy: 0.7428 - precision_0: 0.7883 - recall_0: 0.6786 - F1_0: 0.7279 - precision_1: 0.6762 - recall_1: 0.7847 - F1_1: 0.7255 - val_loss: 0.8739 - val_accuracy: 0.4906 - val_precision_0: 0.7659 - val_recall_0: 0.5119 - val_F1_0: 0.6137 - val_precision_1: 0.1822 - val_recall_1: 0.4100 - val_F1_1: 0.2523
# Epoch 49/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5007 - accuracy: 0.7422 - precision_0: 0.7650 - recall_0: 0.7645 - F1_0: 0.7644 - precision_1: 0.7289 - recall_1: 0.7299 - F1_1: 0.7290 - val_loss: 0.8354 - val_accuracy: 0.4067 - val_precision_0: 0.7260 - val_recall_0: 0.4005 - val_F1_0: 0.5162 - val_precision_1: 0.1599 - val_recall_1: 0.4300 - val_F1_1: 0.2331
# Epoch 50/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.5260 - accuracy: 0.7238 - precision_0: 0.8003 - recall_0: 0.6786 - F1_0: 0.7330 - precision_1: 0.6883 - recall_1: 0.8032 - F1_1: 0.7407 - val_loss: 0.7421 - val_accuracy: 0.5010 - val_precision_0: 0.7584 - val_recall_0: 0.5411 - val_F1_0: 0.6316 - val_precision_1: 0.1683 - val_recall_1: 0.3500 - val_F1_1: 0.2273
# Epoch 51/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.4971 - accuracy: 0.7511 - precision_0: 0.7759 - recall_0: 0.7616 - F1_0: 0.7685 - precision_1: 0.7218 - recall_1: 0.7374 - F1_1: 0.7293 - val_loss: 0.8028 - val_accuracy: 0.4843 - val_precision_0: 0.7673 - val_recall_0: 0.4987 - val_F1_0: 0.6045 - val_precision_1: 0.1853 - val_recall_1: 0.4300 - val_F1_1: 0.2590
# Epoch 52/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4852 - accuracy: 0.7545 - precision_0: 0.7994 - recall_0: 0.7451 - F1_0: 0.7710 - precision_1: 0.7256 - recall_1: 0.7828 - F1_1: 0.7529 - val_loss: 1.0758 - val_accuracy: 0.4025 - val_precision_0: 0.7323 - val_recall_0: 0.3846 - val_F1_0: 0.5043 - val_precision_1: 0.1685 - val_recall_1: 0.4700 - val_F1_1: 0.2480
# Epoch 53/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.4990 - accuracy: 0.7545 - precision_0: 0.8132 - recall_0: 0.7408 - F1_0: 0.7735 - precision_1: 0.7108 - recall_1: 0.7840 - F1_1: 0.7444 - val_loss: 1.0233 - val_accuracy: 0.4633 - val_precision_0: 0.7619 - val_recall_0: 0.4668 - val_F1_0: 0.5789 - val_precision_1: 0.1829 - val_recall_1: 0.4500 - val_F1_1: 0.2601
# Epoch 54/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4873 - accuracy: 0.7467 - precision_0: 0.7894 - recall_0: 0.7417 - F1_0: 0.7642 - precision_1: 0.7232 - recall_1: 0.7720 - F1_1: 0.7462 - val_loss: 1.0026 - val_accuracy: 0.4843 - val_precision_0: 0.7718 - val_recall_0: 0.4934 - val_F1_0: 0.6019 - val_precision_1: 0.1907 - val_recall_1: 0.4500 - val_F1_1: 0.2679
# Epoch 55/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4692 - accuracy: 0.7650 - precision_0: 0.7821 - recall_0: 0.7820 - F1_0: 0.7815 - precision_1: 0.7353 - recall_1: 0.7334 - F1_1: 0.7333 - val_loss: 1.0060 - val_accuracy: 0.4717 - val_precision_0: 0.7572 - val_recall_0: 0.4881 - val_F1_0: 0.5935 - val_precision_1: 0.1752 - val_recall_1: 0.4100 - val_F1_1: 0.2455
# Epoch 56/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4833 - accuracy: 0.7561 - precision_0: 0.7787 - recall_0: 0.7926 - F1_0: 0.7855 - precision_1: 0.7480 - recall_1: 0.7318 - F1_1: 0.7397 - val_loss: 1.0050 - val_accuracy: 0.4948 - val_precision_0: 0.7787 - val_recall_0: 0.5040 - val_F1_0: 0.6119 - val_precision_1: 0.1974 - val_recall_1: 0.4600 - val_F1_1: 0.2763
# Epoch 57/150
# 57/57 [==============================] - 6s 101ms/step - loss: 0.4696 - accuracy: 0.7645 - precision_0: 0.7794 - recall_0: 0.7976 - F1_0: 0.7881 - precision_1: 0.7629 - recall_1: 0.7419 - F1_1: 0.7518 - val_loss: 0.9923 - val_accuracy: 0.4444 - val_precision_0: 0.7523 - val_recall_0: 0.4430 - val_F1_0: 0.5576 - val_precision_1: 0.1765 - val_recall_1: 0.4500 - val_F1_1: 0.2535
# Epoch 58/150
# 57/57 [==============================] - 6s 100ms/step - loss: 0.4549 - accuracy: 0.7879 - precision_0: 0.8074 - recall_0: 0.8339 - F1_0: 0.8202 - precision_1: 0.7853 - recall_1: 0.7531 - F1_1: 0.7685 - val_loss: 1.1985 - val_accuracy: 0.4235 - val_precision_0: 0.7452 - val_recall_0: 0.4111 - val_F1_0: 0.5299 - val_precision_1: 0.1747 - val_recall_1: 0.4700 - val_F1_1: 0.2547
# Epoch 59/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.4561 - accuracy: 0.7712 - precision_0: 0.7916 - recall_0: 0.7697 - F1_0: 0.7801 - precision_1: 0.7517 - recall_1: 0.7738 - F1_1: 0.7623 - val_loss: 1.0884 - val_accuracy: 0.4843 - val_precision_0: 0.7631 - val_recall_0: 0.5040 - val_F1_0: 0.6070 - val_precision_1: 0.1798 - val_recall_1: 0.4100 - val_F1_1: 0.2500
# Epoch 60/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4473 - accuracy: 0.7806 - precision_0: 0.7814 - recall_0: 0.8205 - F1_0: 0.8003 - precision_1: 0.7748 - recall_1: 0.7280 - F1_1: 0.7504 - val_loss: 0.8863 - val_accuracy: 0.5975 - val_precision_0: 0.7480 - val_recall_0: 0.7401 - val_F1_0: 0.7440 - val_precision_1: 0.0577 - val_recall_1: 0.0600 - val_F1_1: 0.0588
# Epoch 61/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4782 - accuracy: 0.7645 - precision_0: 0.7482 - recall_0: 0.8127 - F1_0: 0.7771 - precision_1: 0.7636 - recall_1: 0.6800 - F1_1: 0.7139 - val_loss: 0.8337 - val_accuracy: 0.5220 - val_precision_0: 0.7596 - val_recall_0: 0.5782 - val_F1_0: 0.6566 - val_precision_1: 0.1632 - val_recall_1: 0.3100 - val_F1_1: 0.2138
# Epoch 62/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4374 - accuracy: 0.7912 - precision_0: 0.8046 - recall_0: 0.8165 - F1_0: 0.8104 - precision_1: 0.7873 - recall_1: 0.7738 - F1_1: 0.7803 - val_loss: 0.8981 - val_accuracy: 0.4696 - val_precision_0: 0.7331 - val_recall_0: 0.5172 - val_F1_0: 0.6065 - val_precision_1: 0.1374 - val_recall_1: 0.2900 - val_F1_1: 0.1865
# Epoch 63/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.4227 - accuracy: 0.7945 - precision_0: 0.8056 - recall_0: 0.8428 - F1_0: 0.8237 - precision_1: 0.8028 - recall_1: 0.7588 - F1_1: 0.7800 - val_loss: 1.5331 - val_accuracy: 0.4423 - val_precision_0: 0.7534 - val_recall_0: 0.4377 - val_F1_0: 0.5537 - val_precision_1: 0.1783 - val_recall_1: 0.4600 - val_F1_1: 0.2570
# Epoch 64/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.4479 - accuracy: 0.7773 - precision_0: 0.8036 - recall_0: 0.7985 - F1_0: 0.7999 - precision_1: 0.7776 - recall_1: 0.7779 - F1_1: 0.7768 - val_loss: 1.3454 - val_accuracy: 0.4696 - val_precision_0: 0.7719 - val_recall_0: 0.4668 - val_F1_0: 0.5818 - val_precision_1: 0.1928 - val_recall_1: 0.4800 - val_F1_1: 0.2751
# Epoch 65/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.4370 - accuracy: 0.7851 - precision_0: 0.8063 - recall_0: 0.7778 - F1_0: 0.7909 - precision_1: 0.7649 - recall_1: 0.7920 - F1_1: 0.7775 - val_loss: 0.9951 - val_accuracy: 0.4990 - val_precision_0: 0.7315 - val_recall_0: 0.5782 - val_F1_0: 0.6459 - val_precision_1: 0.1117 - val_recall_1: 0.2000 - val_F1_1: 0.1434
# Epoch 66/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.4173 - accuracy: 0.7940 - precision_0: 0.7982 - recall_0: 0.8303 - F1_0: 0.8135 - precision_1: 0.7859 - recall_1: 0.7475 - F1_1: 0.7656 - val_loss: 1.1766 - val_accuracy: 0.4927 - val_precision_0: 0.7733 - val_recall_0: 0.5066 - val_F1_0: 0.6122 - val_precision_1: 0.1913 - val_recall_1: 0.4400 - val_F1_1: 0.2667
# Epoch 67/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4215 - accuracy: 0.8012 - precision_0: 0.8172 - recall_0: 0.8348 - F1_0: 0.8258 - precision_1: 0.7818 - recall_1: 0.7596 - F1_1: 0.7703 - val_loss: 1.0232 - val_accuracy: 0.4864 - val_precision_0: 0.7727 - val_recall_0: 0.4960 - val_F1_0: 0.6042 - val_precision_1: 0.1915 - val_recall_1: 0.4500 - val_F1_1: 0.2687
# Epoch 68/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.4136 - accuracy: 0.8023 - precision_0: 0.8046 - recall_0: 0.8232 - F1_0: 0.8135 - precision_1: 0.7902 - recall_1: 0.7679 - F1_1: 0.7785 - val_loss: 1.3006 - val_accuracy: 0.4738 - val_precision_0: 0.7461 - val_recall_0: 0.5066 - val_F1_0: 0.6035 - val_precision_1: 0.1584 - val_recall_1: 0.3500 - val_F1_1: 0.2181
# Epoch 69/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4001 - accuracy: 0.8046 - precision_0: 0.7907 - recall_0: 0.8597 - F1_0: 0.8231 - precision_1: 0.8208 - recall_1: 0.7383 - F1_1: 0.7764 - val_loss: 0.9663 - val_accuracy: 0.5304 - val_precision_0: 0.7413 - val_recall_0: 0.6233 - val_F1_0: 0.6772 - val_precision_1: 0.1125 - val_recall_1: 0.1800 - val_F1_1: 0.1385
# Epoch 70/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3941 - accuracy: 0.8140 - precision_0: 0.8206 - recall_0: 0.8322 - F1_0: 0.8262 - precision_1: 0.7975 - recall_1: 0.7829 - F1_1: 0.7899 - val_loss: 1.3461 - val_accuracy: 0.3564 - val_precision_0: 0.6768 - val_recall_0: 0.3554 - val_F1_0: 0.4661 - val_precision_1: 0.1290 - val_recall_1: 0.3600 - val_F1_1: 0.1900
# Epoch 71/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.4078 - accuracy: 0.8073 - precision_0: 0.8394 - recall_0: 0.7990 - F1_0: 0.8180 - precision_1: 0.7793 - recall_1: 0.8204 - F1_1: 0.7987 - val_loss: 1.5895 - val_accuracy: 0.4612 - val_precision_0: 0.7586 - val_recall_0: 0.4668 - val_F1_0: 0.5780 - val_precision_1: 0.1796 - val_recall_1: 0.4400 - val_F1_1: 0.2551
# Epoch 72/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.3891 - accuracy: 0.8185 - precision_0: 0.8251 - recall_0: 0.8373 - F1_0: 0.8310 - precision_1: 0.8155 - recall_1: 0.8019 - F1_1: 0.8085 - val_loss: 1.1026 - val_accuracy: 0.4444 - val_precision_0: 0.7523 - val_recall_0: 0.4430 - val_F1_0: 0.5576 - val_precision_1: 0.1765 - val_recall_1: 0.4500 - val_F1_1: 0.2535
# Epoch 73/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3947 - accuracy: 0.8085 - precision_0: 0.8333 - recall_0: 0.8211 - F1_0: 0.8270 - precision_1: 0.7887 - recall_1: 0.8018 - F1_1: 0.7949 - val_loss: 1.0376 - val_accuracy: 0.5031 - val_precision_0: 0.7652 - val_recall_0: 0.5358 - val_F1_0: 0.6303 - val_precision_1: 0.1784 - val_recall_1: 0.3800 - val_F1_1: 0.2428
# Epoch 74/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.3884 - accuracy: 0.8129 - precision_0: 0.8190 - recall_0: 0.8245 - F1_0: 0.8214 - precision_1: 0.7927 - recall_1: 0.7869 - F1_1: 0.7893 - val_loss: 1.3074 - val_accuracy: 0.4151 - val_precision_0: 0.7311 - val_recall_0: 0.4111 - val_F1_0: 0.5263 - val_precision_1: 0.1623 - val_recall_1: 0.4300 - val_F1_1: 0.2356
# Epoch 75/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3992 - accuracy: 0.8018 - precision_0: 0.8493 - recall_0: 0.7935 - F1_0: 0.8195 - precision_1: 0.7837 - recall_1: 0.8387 - F1_1: 0.8096 - val_loss: 1.1445 - val_accuracy: 0.4801 - val_precision_0: 0.7529 - val_recall_0: 0.5093 - val_F1_0: 0.6076 - val_precision_1: 0.1667 - val_recall_1: 0.3700 - val_F1_1: 0.2298
# Epoch 76/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3864 - accuracy: 0.8174 - precision_0: 0.8310 - recall_0: 0.8547 - F1_0: 0.8426 - precision_1: 0.8232 - recall_1: 0.7958 - F1_1: 0.8091 - val_loss: 1.0459 - val_accuracy: 0.4948 - val_precision_0: 0.7787 - val_recall_0: 0.5040 - val_F1_0: 0.6119 - val_precision_1: 0.1974 - val_recall_1: 0.4600 - val_F1_1: 0.2763
# Epoch 77/150
# 57/57 [==============================] - 6s 104ms/step - loss: 0.3656 - accuracy: 0.8235 - precision_0: 0.8392 - recall_0: 0.8353 - F1_0: 0.8372 - precision_1: 0.8049 - recall_1: 0.8084 - F1_1: 0.8065 - val_loss: 1.2032 - val_accuracy: 0.4927 - val_precision_0: 0.7586 - val_recall_0: 0.5252 - val_F1_0: 0.6207 - val_precision_1: 0.1713 - val_recall_1: 0.3700 - val_F1_1: 0.2342
# Epoch 78/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.3566 - accuracy: 0.8280 - precision_0: 0.8482 - recall_0: 0.8298 - F1_0: 0.8388 - precision_1: 0.8128 - recall_1: 0.8323 - F1_1: 0.8223 - val_loss: 1.2624 - val_accuracy: 0.4361 - val_precision_0: 0.7432 - val_recall_0: 0.4377 - val_F1_0: 0.5509 - val_precision_1: 0.1686 - val_recall_1: 0.4300 - val_F1_1: 0.2423
# Epoch 79/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3358 - accuracy: 0.8391 - precision_0: 0.8461 - recall_0: 0.8504 - F1_0: 0.8480 - precision_1: 0.8224 - recall_1: 0.8176 - F1_1: 0.8197 - val_loss: 1.5770 - val_accuracy: 0.3962 - val_precision_0: 0.7171 - val_recall_0: 0.3899 - val_F1_0: 0.5052 - val_precision_1: 0.1544 - val_recall_1: 0.4200 - val_F1_1: 0.2258
# Epoch 80/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3461 - accuracy: 0.8280 - precision_0: 0.8553 - recall_0: 0.8583 - F1_0: 0.8567 - precision_1: 0.8145 - recall_1: 0.8107 - F1_1: 0.8123 - val_loss: 1.8785 - val_accuracy: 0.3585 - val_precision_0: 0.6919 - val_recall_0: 0.3395 - val_F1_0: 0.4555 - val_precision_1: 0.1473 - val_recall_1: 0.4300 - val_F1_1: 0.2194
# Epoch 81/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.3632 - accuracy: 0.8263 - precision_0: 0.8473 - recall_0: 0.8204 - F1_0: 0.8335 - precision_1: 0.7891 - recall_1: 0.8196 - F1_1: 0.8039 - val_loss: 1.4085 - val_accuracy: 0.4696 - val_precision_0: 0.7627 - val_recall_0: 0.4775 - val_F1_0: 0.5873 - val_precision_1: 0.1826 - val_recall_1: 0.4400 - val_F1_1: 0.2581
# Epoch 82/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3391 - accuracy: 0.8369 - precision_0: 0.8521 - recall_0: 0.8611 - F1_0: 0.8564 - precision_1: 0.8258 - recall_1: 0.8149 - F1_1: 0.8199 - val_loss: 1.2615 - val_accuracy: 0.4109 - val_precision_0: 0.7182 - val_recall_0: 0.4191 - val_F1_0: 0.5293 - val_precision_1: 0.1479 - val_recall_1: 0.3800 - val_F1_1: 0.2129
# Epoch 83/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3361 - accuracy: 0.8380 - precision_0: 0.8497 - recall_0: 0.8600 - F1_0: 0.8547 - precision_1: 0.8379 - recall_1: 0.8260 - F1_1: 0.8319 - val_loss: 1.3778 - val_accuracy: 0.4465 - val_precision_0: 0.7011 - val_recall_0: 0.5225 - val_F1_0: 0.5988 - val_precision_1: 0.0816 - val_recall_1: 0.1600 - val_F1_1: 0.1081
# Epoch 84/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3401 - accuracy: 0.8307 - precision_0: 0.8326 - recall_0: 0.8463 - F1_0: 0.8390 - precision_1: 0.8207 - recall_1: 0.8050 - F1_1: 0.8122 - val_loss: 1.5628 - val_accuracy: 0.4130 - val_precision_0: 0.6996 - val_recall_0: 0.4509 - val_F1_0: 0.5484 - val_precision_1: 0.1154 - val_recall_1: 0.2700 - val_F1_1: 0.1617
# Epoch 85/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.3285 - accuracy: 0.8447 - precision_0: 0.8628 - recall_0: 0.8548 - F1_0: 0.8587 - precision_1: 0.8389 - recall_1: 0.8475 - F1_1: 0.8431 - val_loss: 1.2096 - val_accuracy: 0.5535 - val_precision_0: 0.7752 - val_recall_0: 0.6127 - val_F1_0: 0.6844 - val_precision_1: 0.1844 - val_recall_1: 0.3300 - val_F1_1: 0.2366
# Epoch 86/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3377 - accuracy: 0.8313 - precision_0: 0.8430 - recall_0: 0.8594 - F1_0: 0.8508 - precision_1: 0.8405 - recall_1: 0.8194 - F1_1: 0.8293 - val_loss: 1.1563 - val_accuracy: 0.5157 - val_precision_0: 0.7450 - val_recall_0: 0.5889 - val_F1_0: 0.6578 - val_precision_1: 0.1341 - val_recall_1: 0.2400 - val_F1_1: 0.1720
# Epoch 87/150
# 57/57 [==============================] - 5s 94ms/step - loss: 0.3211 - accuracy: 0.8413 - precision_0: 0.8428 - recall_0: 0.8683 - F1_0: 0.8549 - precision_1: 0.8498 - recall_1: 0.8212 - F1_1: 0.8347 - val_loss: 1.8753 - val_accuracy: 0.3061 - val_precision_0: 0.6402 - val_recall_0: 0.2785 - val_F1_0: 0.3882 - val_precision_1: 0.1310 - val_recall_1: 0.4100 - val_F1_1: 0.1985
# Epoch 88/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3160 - accuracy: 0.8502 - precision_0: 0.8744 - recall_0: 0.8615 - F1_0: 0.8677 - precision_1: 0.8438 - recall_1: 0.8576 - F1_1: 0.8504 - val_loss: 1.5712 - val_accuracy: 0.4885 - val_precision_0: 0.7588 - val_recall_0: 0.5172 - val_F1_0: 0.6151 - val_precision_1: 0.1727 - val_recall_1: 0.3800 - val_F1_1: 0.2375
# Epoch 89/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.3411 - accuracy: 0.8419 - precision_0: 0.8701 - recall_0: 0.8682 - F1_0: 0.8690 - precision_1: 0.8413 - recall_1: 0.8428 - F1_1: 0.8419 - val_loss: 1.3591 - val_accuracy: 0.4151 - val_precision_0: 0.6976 - val_recall_0: 0.4589 - val_F1_0: 0.5536 - val_precision_1: 0.1092 - val_recall_1: 0.2500 - val_F1_1: 0.1520
# Epoch 90/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.3182 - accuracy: 0.8491 - precision_0: 0.8597 - recall_0: 0.8658 - F1_0: 0.8624 - precision_1: 0.8265 - recall_1: 0.8204 - F1_1: 0.8226 - val_loss: 1.8896 - val_accuracy: 0.4193 - val_precision_0: 0.7232 - val_recall_0: 0.4297 - val_F1_0: 0.5391 - val_precision_1: 0.1502 - val_recall_1: 0.3800 - val_F1_1: 0.2153
# Epoch 91/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.3197 - accuracy: 0.8463 - precision_0: 0.8651 - recall_0: 0.8571 - F1_0: 0.8609 - precision_1: 0.8436 - recall_1: 0.8520 - F1_1: 0.8476 - val_loss: 1.3944 - val_accuracy: 0.3543 - val_precision_0: 0.6561 - val_recall_0: 0.3846 - val_F1_0: 0.4849 - val_precision_1: 0.0938 - val_recall_1: 0.2400 - val_F1_1: 0.1348
# Epoch 92/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.2970 - accuracy: 0.8597 - precision_0: 0.8780 - recall_0: 0.8705 - F1_0: 0.8742 - precision_1: 0.8562 - recall_1: 0.8642 - F1_1: 0.8601 - val_loss: 1.3382 - val_accuracy: 0.4591 - val_precision_0: 0.7297 - val_recall_0: 0.5013 - val_F1_0: 0.5943 - val_precision_1: 0.1376 - val_recall_1: 0.3000 - val_F1_1: 0.1887
# Epoch 93/150
# 57/57 [==============================] - 6s 104ms/step - loss: 0.3096 - accuracy: 0.8591 - precision_0: 0.8755 - recall_0: 0.8824 - F1_0: 0.8786 - precision_1: 0.8645 - recall_1: 0.8573 - F1_1: 0.8605 - val_loss: 1.6807 - val_accuracy: 0.4403 - val_precision_0: 0.7254 - val_recall_0: 0.4695 - val_F1_0: 0.5700 - val_precision_1: 0.1416 - val_recall_1: 0.3300 - val_F1_1: 0.1982
# Epoch 94/150
# 57/57 [==============================] - 6s 113ms/step - loss: 0.3087 - accuracy: 0.8463 - precision_0: 0.8597 - recall_0: 0.8533 - F1_0: 0.8564 - precision_1: 0.8302 - recall_1: 0.8377 - F1_1: 0.8338 - val_loss: 1.6210 - val_accuracy: 0.4298 - val_precision_0: 0.7027 - val_recall_0: 0.4828 - val_F1_0: 0.5723 - val_precision_1: 0.1055 - val_recall_1: 0.2300 - val_F1_1: 0.1447
# Epoch 95/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.3002 - accuracy: 0.8508 - precision_0: 0.8737 - recall_0: 0.8668 - F1_0: 0.8700 - precision_1: 0.8481 - recall_1: 0.8572 - F1_1: 0.8522 - val_loss: 1.3418 - val_accuracy: 0.4151 - val_precision_0: 0.6870 - val_recall_0: 0.4775 - val_F1_0: 0.5634 - val_precision_1: 0.0837 - val_recall_1: 0.1800 - val_F1_1: 0.1143
# Epoch 96/150
# 57/57 [==============================] - 6s 108ms/step - loss: 0.2863 - accuracy: 0.8614 - precision_0: 0.8677 - recall_0: 0.8816 - F1_0: 0.8740 - precision_1: 0.8633 - recall_1: 0.8472 - F1_1: 0.8543 - val_loss: 1.6364 - val_accuracy: 0.4906 - val_precision_0: 0.7839 - val_recall_0: 0.4907 - val_F1_0: 0.6036 - val_precision_1: 0.2033 - val_recall_1: 0.4900 - val_F1_1: 0.2874
# Epoch 97/150
# 57/57 [==============================] - 6s 111ms/step - loss: 0.3153 - accuracy: 0.8463 - precision_0: 0.8700 - recall_0: 0.8654 - F1_0: 0.8676 - precision_1: 0.8377 - recall_1: 0.8434 - F1_1: 0.8403 - val_loss: 1.4381 - val_accuracy: 0.3229 - val_precision_0: 0.6436 - val_recall_0: 0.3210 - val_F1_0: 0.4283 - val_precision_1: 0.1142 - val_recall_1: 0.3300 - val_F1_1: 0.1697
# Epoch 98/150
# 57/57 [==============================] - 6s 112ms/step - loss: 0.3076 - accuracy: 0.8563 - precision_0: 0.8686 - recall_0: 0.8519 - F1_0: 0.8600 - precision_1: 0.8301 - recall_1: 0.8483 - F1_1: 0.8390 - val_loss: 1.4652 - val_accuracy: 0.4130 - val_precision_0: 0.7235 - val_recall_0: 0.4164 - val_F1_0: 0.5286 - val_precision_1: 0.1538 - val_recall_1: 0.4000 - val_F1_1: 0.2222
# Epoch 99/150
# 57/57 [==============================] - 6s 114ms/step - loss: 0.2903 - accuracy: 0.8647 - precision_0: 0.8414 - recall_0: 0.8567 - F1_0: 0.8487 - precision_1: 0.8441 - recall_1: 0.8275 - F1_1: 0.8356 - val_loss: 1.7691 - val_accuracy: 0.5073 - val_precision_0: 0.7290 - val_recall_0: 0.5995 - val_F1_0: 0.6579 - val_precision_1: 0.0958 - val_recall_1: 0.1600 - val_F1_1: 0.1199
# Epoch 100/150
# 57/57 [==============================] - 6s 114ms/step - loss: 0.3293 - accuracy: 0.8413 - precision_0: 0.8268 - recall_0: 0.8734 - F1_0: 0.8488 - precision_1: 0.8435 - recall_1: 0.7835 - F1_1: 0.8109 - val_loss: 1.2533 - val_accuracy: 0.4528 - val_precision_0: 0.7000 - val_recall_0: 0.5385 - val_F1_0: 0.6087 - val_precision_1: 0.0695 - val_recall_1: 0.1300 - val_F1_1: 0.0906
# Epoch 101/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.2989 - accuracy: 0.8502 - precision_0: 0.8578 - recall_0: 0.8737 - F1_0: 0.8656 - precision_1: 0.8554 - recall_1: 0.8376 - F1_1: 0.8463 - val_loss: 1.5151 - val_accuracy: 0.2809 - val_precision_0: 0.5859 - val_recall_0: 0.3077 - val_F1_0: 0.4035 - val_precision_1: 0.0645 - val_recall_1: 0.1800 - val_F1_1: 0.0950
# Epoch 102/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.2893 - accuracy: 0.8664 - precision_0: 0.8717 - recall_0: 0.8752 - F1_0: 0.8732 - precision_1: 0.8547 - recall_1: 0.8489 - F1_1: 0.8514 - val_loss: 1.4925 - val_accuracy: 0.4235 - val_precision_0: 0.6889 - val_recall_0: 0.4934 - val_F1_0: 0.5750 - val_precision_1: 0.0773 - val_recall_1: 0.1600 - val_F1_1: 0.1042
# Epoch 103/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2924 - accuracy: 0.8536 - precision_0: 0.8607 - recall_0: 0.8757 - F1_0: 0.8681 - precision_1: 0.8503 - recall_1: 0.8327 - F1_1: 0.8413 - val_loss: 1.5043 - val_accuracy: 0.4403 - val_precision_0: 0.6993 - val_recall_0: 0.5119 - val_F1_0: 0.5911 - val_precision_1: 0.0846 - val_recall_1: 0.1700 - val_F1_1: 0.1130
# Epoch 104/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2876 - accuracy: 0.8586 - precision_0: 0.8643 - recall_0: 0.8735 - F1_0: 0.8687 - precision_1: 0.8595 - recall_1: 0.8509 - F1_1: 0.8550 - val_loss: 1.8057 - val_accuracy: 0.3753 - val_precision_0: 0.7182 - val_recall_0: 0.3448 - val_F1_0: 0.4659 - val_precision_1: 0.1655 - val_recall_1: 0.4900 - val_F1_1: 0.2475
# Epoch 105/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2832 - accuracy: 0.8742 - precision_0: 0.8859 - recall_0: 0.8894 - F1_0: 0.8873 - precision_1: 0.8619 - recall_1: 0.8555 - F1_1: 0.8582 - val_loss: 1.8405 - val_accuracy: 0.2977 - val_precision_0: 0.6167 - val_recall_0: 0.2944 - val_F1_0: 0.3986 - val_precision_1: 0.1044 - val_recall_1: 0.3100 - val_F1_1: 0.1562
# Epoch 106/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2861 - accuracy: 0.8575 - precision_0: 0.8923 - recall_0: 0.8432 - F1_0: 0.8661 - precision_1: 0.8300 - recall_1: 0.8808 - F1_1: 0.8537 - val_loss: 1.6896 - val_accuracy: 0.4843 - val_precision_0: 0.7529 - val_recall_0: 0.5172 - val_F1_0: 0.6132 - val_precision_1: 0.1651 - val_recall_1: 0.3600 - val_F1_1: 0.2264
# Epoch 107/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2852 - accuracy: 0.8653 - precision_0: 0.8664 - recall_0: 0.8729 - F1_0: 0.8694 - precision_1: 0.8574 - recall_1: 0.8486 - F1_1: 0.8526 - val_loss: 1.5064 - val_accuracy: 0.4654 - val_precision_0: 0.7293 - val_recall_0: 0.5146 - val_F1_0: 0.6034 - val_precision_1: 0.1327 - val_recall_1: 0.2800 - val_F1_1: 0.1801
# Epoch 108/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2751 - accuracy: 0.8636 - precision_0: 0.8631 - recall_0: 0.8908 - F1_0: 0.8766 - precision_1: 0.8696 - recall_1: 0.8376 - F1_1: 0.8531 - val_loss: 1.7021 - val_accuracy: 0.3669 - val_precision_0: 0.6847 - val_recall_0: 0.3687 - val_F1_0: 0.4793 - val_precision_1: 0.1314 - val_recall_1: 0.3600 - val_F1_1: 0.1925
# Epoch 109/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2736 - accuracy: 0.8758 - precision_0: 0.8885 - recall_0: 0.8866 - F1_0: 0.8875 - precision_1: 0.8730 - recall_1: 0.8733 - F1_1: 0.8731 - val_loss: 1.8134 - val_accuracy: 0.4403 - val_precision_0: 0.6910 - val_recall_0: 0.5279 - val_F1_0: 0.5985 - val_precision_1: 0.0582 - val_recall_1: 0.1100 - val_F1_1: 0.0761
# Epoch 110/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2800 - accuracy: 0.8653 - precision_0: 0.8937 - recall_0: 0.8788 - F1_0: 0.8858 - precision_1: 0.8547 - recall_1: 0.8713 - F1_1: 0.8624 - val_loss: 1.8868 - val_accuracy: 0.4465 - val_precision_0: 0.7344 - val_recall_0: 0.4695 - val_F1_0: 0.5728 - val_precision_1: 0.1525 - val_recall_1: 0.3600 - val_F1_1: 0.2143
# Epoch 111/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2611 - accuracy: 0.8731 - precision_0: 0.8783 - recall_0: 0.8967 - F1_0: 0.8873 - precision_1: 0.8773 - recall_1: 0.8555 - F1_1: 0.8661 - val_loss: 1.5653 - val_accuracy: 0.4235 - val_precision_0: 0.7008 - val_recall_0: 0.4721 - val_F1_0: 0.5642 - val_precision_1: 0.1076 - val_recall_1: 0.2400 - val_F1_1: 0.1486
# Epoch 112/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2782 - accuracy: 0.8664 - precision_0: 0.8649 - recall_0: 0.8740 - F1_0: 0.8692 - precision_1: 0.8481 - recall_1: 0.8359 - F1_1: 0.8415 - val_loss: 1.9089 - val_accuracy: 0.5325 - val_precision_0: 0.7567 - val_recall_0: 0.6021 - val_F1_0: 0.6706 - val_precision_1: 0.1525 - val_recall_1: 0.2700 - val_F1_1: 0.1949
# Epoch 113/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2724 - accuracy: 0.8731 - precision_0: 0.8748 - recall_0: 0.9160 - F1_0: 0.8947 - precision_1: 0.8959 - recall_1: 0.8473 - F1_1: 0.8706 - val_loss: 2.0616 - val_accuracy: 0.4444 - val_precision_0: 0.7205 - val_recall_0: 0.4854 - val_F1_0: 0.5800 - val_precision_1: 0.1300 - val_recall_1: 0.2900 - val_F1_1: 0.1796
# Epoch 114/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2723 - accuracy: 0.8719 - precision_0: 0.8866 - recall_0: 0.8765 - F1_0: 0.8812 - precision_1: 0.8515 - recall_1: 0.8636 - F1_1: 0.8572 - val_loss: 1.5238 - val_accuracy: 0.4486 - val_precision_0: 0.7415 - val_recall_0: 0.4642 - val_F1_0: 0.5710 - val_precision_1: 0.1618 - val_recall_1: 0.3900 - val_F1_1: 0.2287
# Epoch 115/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2688 - accuracy: 0.8686 - precision_0: 0.8813 - recall_0: 0.8884 - F1_0: 0.8847 - precision_1: 0.8574 - recall_1: 0.8489 - F1_1: 0.8530 - val_loss: 1.8849 - val_accuracy: 0.4382 - val_precision_0: 0.7512 - val_recall_0: 0.4324 - val_F1_0: 0.5488 - val_precision_1: 0.1769 - val_recall_1: 0.4600 - val_F1_1: 0.2556
# Epoch 116/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2527 - accuracy: 0.8808 - precision_0: 0.8948 - recall_0: 0.8864 - F1_0: 0.8905 - precision_1: 0.8640 - recall_1: 0.8734 - F1_1: 0.8686 - val_loss: 1.8438 - val_accuracy: 0.3878 - val_precision_0: 0.7348 - val_recall_0: 0.3528 - val_F1_0: 0.4767 - val_precision_1: 0.1757 - val_recall_1: 0.5200 - val_F1_1: 0.2626
# Epoch 117/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2384 - accuracy: 0.8836 - precision_0: 0.8899 - recall_0: 0.8827 - F1_0: 0.8861 - precision_1: 0.8534 - recall_1: 0.8618 - F1_1: 0.8573 - val_loss: 2.1312 - val_accuracy: 0.2893 - val_precision_0: 0.5950 - val_recall_0: 0.3156 - val_F1_0: 0.4125 - val_precision_1: 0.0686 - val_recall_1: 0.1900 - val_F1_1: 0.1008
# Epoch 118/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2522 - accuracy: 0.8753 - precision_0: 0.9005 - recall_0: 0.8905 - F1_0: 0.8950 - precision_1: 0.8691 - recall_1: 0.8791 - F1_1: 0.8735 - val_loss: 2.0465 - val_accuracy: 0.4486 - val_precision_0: 0.7355 - val_recall_0: 0.4721 - val_F1_0: 0.5751 - val_precision_1: 0.1532 - val_recall_1: 0.3600 - val_F1_1: 0.2149
# Epoch 119/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2794 - accuracy: 0.8747 - precision_0: 0.8808 - recall_0: 0.8710 - F1_0: 0.8754 - precision_1: 0.8576 - recall_1: 0.8658 - F1_1: 0.8612 - val_loss: 1.9839 - val_accuracy: 0.5073 - val_precision_0: 0.7591 - val_recall_0: 0.5517 - val_F1_0: 0.6390 - val_precision_1: 0.1675 - val_recall_1: 0.3400 - val_F1_1: 0.2244
# Epoch 120/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2341 - accuracy: 0.8892 - precision_0: 0.8960 - recall_0: 0.8945 - F1_0: 0.8951 - precision_1: 0.8735 - recall_1: 0.8765 - F1_1: 0.8747 - val_loss: 2.0230 - val_accuracy: 0.2956 - val_precision_0: 0.6306 - val_recall_0: 0.2626 - val_F1_0: 0.3708 - val_precision_1: 0.1312 - val_recall_1: 0.4200 - val_F1_1: 0.2000
# Epoch 121/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2539 - accuracy: 0.8875 - precision_0: 0.9023 - recall_0: 0.9049 - F1_0: 0.9034 - precision_1: 0.8833 - recall_1: 0.8793 - F1_1: 0.8811 - val_loss: 1.8238 - val_accuracy: 0.4465 - val_precision_0: 0.7085 - val_recall_0: 0.5093 - val_F1_0: 0.5926 - val_precision_1: 0.1019 - val_recall_1: 0.2100 - val_F1_1: 0.1373
# Epoch 122/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2468 - accuracy: 0.8881 - precision_0: 0.8894 - recall_0: 0.8881 - F1_0: 0.8886 - precision_1: 0.8775 - recall_1: 0.8800 - F1_1: 0.8786 - val_loss: 1.6001 - val_accuracy: 0.5493 - val_precision_0: 0.7630 - val_recall_0: 0.6233 - val_F1_0: 0.6861 - val_precision_1: 0.1598 - val_recall_1: 0.2700 - val_F1_1: 0.2007
# Epoch 123/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2571 - accuracy: 0.8808 - precision_0: 0.8801 - recall_0: 0.9015 - F1_0: 0.8904 - precision_1: 0.8816 - recall_1: 0.8538 - F1_1: 0.8669 - val_loss: 2.0659 - val_accuracy: 0.3816 - val_precision_0: 0.6640 - val_recall_0: 0.4403 - val_F1_0: 0.5295 - val_precision_1: 0.0705 - val_recall_1: 0.1600 - val_F1_1: 0.0979
# Epoch 124/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2397 - accuracy: 0.8769 - precision_0: 0.8795 - recall_0: 0.8807 - F1_0: 0.8801 - precision_1: 0.8545 - recall_1: 0.8524 - F1_1: 0.8534 - val_loss: 1.6748 - val_accuracy: 0.4088 - val_precision_0: 0.6923 - val_recall_0: 0.4536 - val_F1_0: 0.5481 - val_precision_1: 0.1043 - val_recall_1: 0.2400 - val_F1_1: 0.1455
# Epoch 125/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2259 - accuracy: 0.9014 - precision_0: 0.9196 - recall_0: 0.9178 - F1_0: 0.9187 - precision_1: 0.9113 - recall_1: 0.9130 - F1_1: 0.9121 - val_loss: 1.6144 - val_accuracy: 0.5409 - val_precision_0: 0.7582 - val_recall_0: 0.6154 - val_F1_0: 0.6794 - val_precision_1: 0.1520 - val_recall_1: 0.2600 - val_F1_1: 0.1919
# Epoch 126/150
# 57/57 [==============================] - 7s 115ms/step - loss: 0.2474 - accuracy: 0.8942 - precision_0: 0.8949 - recall_0: 0.9222 - F1_0: 0.9079 - precision_1: 0.9093 - recall_1: 0.8787 - F1_1: 0.8933 - val_loss: 2.0836 - val_accuracy: 0.4465 - val_precision_0: 0.7489 - val_recall_0: 0.4509 - val_F1_0: 0.5629 - val_precision_1: 0.1720 - val_recall_1: 0.4300 - val_F1_1: 0.2457
# Epoch 127/150
# 57/57 [==============================] - 6s 113ms/step - loss: 0.2234 - accuracy: 0.8998 - precision_0: 0.9072 - recall_0: 0.9084 - F1_0: 0.9077 - precision_1: 0.8868 - recall_1: 0.8849 - F1_1: 0.8857 - val_loss: 2.2997 - val_accuracy: 0.4969 - val_precision_0: 0.7645 - val_recall_0: 0.5252 - val_F1_0: 0.6226 - val_precision_1: 0.1789 - val_recall_1: 0.3900 - val_F1_1: 0.2453
# Epoch 128/150
# 57/57 [==============================] - 6s 109ms/step - loss: 0.2326 - accuracy: 0.8948 - precision_0: 0.8996 - recall_0: 0.9008 - F1_0: 0.9001 - precision_1: 0.8824 - recall_1: 0.8801 - F1_1: 0.8811 - val_loss: 1.9734 - val_accuracy: 0.4172 - val_precision_0: 0.7089 - val_recall_0: 0.4456 - val_F1_0: 0.5472 - val_precision_1: 0.1292 - val_recall_1: 0.3100 - val_F1_1: 0.1824
# Epoch 129/150
# 57/57 [==============================] - 7s 117ms/step - loss: 0.2311 - accuracy: 0.8953 - precision_0: 0.9054 - recall_0: 0.8829 - F1_0: 0.8934 - precision_1: 0.8565 - recall_1: 0.8838 - F1_1: 0.8689 - val_loss: 1.9267 - val_accuracy: 0.3522 - val_precision_0: 0.6667 - val_recall_0: 0.3607 - val_F1_0: 0.4682 - val_precision_1: 0.1172 - val_recall_1: 0.3200 - val_F1_1: 0.1716
# Epoch 130/150
# 57/57 [==============================] - 6s 112ms/step - loss: 0.2379 - accuracy: 0.8909 - precision_0: 0.8922 - recall_0: 0.9179 - F1_0: 0.9046 - precision_1: 0.9006 - recall_1: 0.8703 - F1_1: 0.8849 - val_loss: 1.8865 - val_accuracy: 0.4340 - val_precision_0: 0.7296 - val_recall_0: 0.4509 - val_F1_0: 0.5574 - val_precision_1: 0.1516 - val_recall_1: 0.3700 - val_F1_1: 0.2151
# Epoch 131/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2428 - accuracy: 0.8925 - precision_0: 0.8962 - recall_0: 0.9042 - F1_0: 0.9001 - precision_1: 0.8945 - recall_1: 0.8860 - F1_1: 0.8902 - val_loss: 1.7017 - val_accuracy: 0.4738 - val_precision_0: 0.7283 - val_recall_0: 0.5332 - val_F1_0: 0.6156 - val_precision_1: 0.1244 - val_recall_1: 0.2500 - val_F1_1: 0.1661
# Epoch 132/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2228 - accuracy: 0.8976 - precision_0: 0.9074 - recall_0: 0.9245 - F1_0: 0.9158 - precision_1: 0.9080 - recall_1: 0.8860 - F1_1: 0.8967 - val_loss: 2.2591 - val_accuracy: 0.5073 - val_precision_0: 0.7383 - val_recall_0: 0.5836 - val_F1_0: 0.6519 - val_precision_1: 0.1229 - val_recall_1: 0.2200 - val_F1_1: 0.1577
# Epoch 133/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2423 - accuracy: 0.8814 - precision_0: 0.8810 - recall_0: 0.9060 - F1_0: 0.8932 - precision_1: 0.8859 - recall_1: 0.8548 - F1_1: 0.8698 - val_loss: 2.5140 - val_accuracy: 0.3836 - val_precision_0: 0.7219 - val_recall_0: 0.3581 - val_F1_0: 0.4787 - val_precision_1: 0.1655 - val_recall_1: 0.4800 - val_F1_1: 0.2462
# Epoch 134/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2489 - accuracy: 0.8808 - precision_0: 0.8898 - recall_0: 0.8968 - F1_0: 0.8933 - precision_1: 0.8795 - recall_1: 0.8716 - F1_1: 0.8755 - val_loss: 2.5442 - val_accuracy: 0.3312 - val_precision_0: 0.6835 - val_recall_0: 0.2865 - val_F1_0: 0.4037 - val_precision_1: 0.1567 - val_recall_1: 0.5000 - val_F1_1: 0.2387
# Epoch 135/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2587 - accuracy: 0.8797 - precision_0: 0.8950 - recall_0: 0.8953 - F1_0: 0.8950 - precision_1: 0.8707 - recall_1: 0.8702 - F1_1: 0.8702 - val_loss: 1.7530 - val_accuracy: 0.5283 - val_precision_0: 0.7436 - val_recall_0: 0.6154 - val_F1_0: 0.6734 - val_precision_1: 0.1212 - val_recall_1: 0.2000 - val_F1_1: 0.1509
# Epoch 136/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2779 - accuracy: 0.8753 - precision_0: 0.8595 - recall_0: 0.8930 - F1_0: 0.8756 - precision_1: 0.8712 - recall_1: 0.8288 - F1_1: 0.8488 - val_loss: 1.7993 - val_accuracy: 0.5409 - val_precision_0: 0.7821 - val_recall_0: 0.5809 - val_F1_0: 0.6667 - val_precision_1: 0.1980 - val_recall_1: 0.3900 - val_F1_1: 0.2626
# Epoch 137/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2383 - accuracy: 0.8881 - precision_0: 0.8948 - recall_0: 0.8935 - F1_0: 0.8939 - precision_1: 0.8730 - recall_1: 0.8759 - F1_1: 0.8742 - val_loss: 1.8123 - val_accuracy: 0.4801 - val_precision_0: 0.7452 - val_recall_0: 0.5199 - val_F1_0: 0.6125 - val_precision_1: 0.1542 - val_recall_1: 0.3300 - val_F1_1: 0.2102
# Epoch 138/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2195 - accuracy: 0.9092 - precision_0: 0.9088 - recall_0: 0.9134 - F1_0: 0.9110 - precision_1: 0.9055 - recall_1: 0.8997 - F1_1: 0.9025 - val_loss: 2.2627 - val_accuracy: 0.4046 - val_precision_0: 0.7246 - val_recall_0: 0.3979 - val_F1_0: 0.5137 - val_precision_1: 0.1593 - val_recall_1: 0.4300 - val_F1_1: 0.2324
# Epoch 139/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2380 - accuracy: 0.8948 - precision_0: 0.9068 - recall_0: 0.9147 - F1_0: 0.9104 - precision_1: 0.8880 - recall_1: 0.8795 - F1_1: 0.8831 - val_loss: 1.8951 - val_accuracy: 0.3585 - val_precision_0: 0.6682 - val_recall_0: 0.3740 - val_F1_0: 0.4796 - val_precision_1: 0.1128 - val_recall_1: 0.3000 - val_F1_1: 0.1639
# Epoch 140/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2190 - accuracy: 0.9059 - precision_0: 0.8949 - recall_0: 0.9104 - F1_0: 0.9025 - precision_1: 0.8886 - recall_1: 0.8692 - F1_1: 0.8787 - val_loss: 2.1168 - val_accuracy: 0.4696 - val_precision_0: 0.7500 - val_recall_0: 0.4934 - val_F1_0: 0.5952 - val_precision_1: 0.1659 - val_recall_1: 0.3800 - val_F1_1: 0.2310
# Epoch 141/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2011 - accuracy: 0.9092 - precision_0: 0.9140 - recall_0: 0.9204 - F1_0: 0.9171 - precision_1: 0.9039 - recall_1: 0.8962 - F1_1: 0.8999 - val_loss: 1.9431 - val_accuracy: 0.5241 - val_precision_0: 0.7568 - val_recall_0: 0.5862 - val_F1_0: 0.6607 - val_precision_1: 0.1568 - val_recall_1: 0.2900 - val_F1_1: 0.2035
# Epoch 142/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2513 - accuracy: 0.8931 - precision_0: 0.9039 - recall_0: 0.9096 - F1_0: 0.9067 - precision_1: 0.8900 - recall_1: 0.8830 - F1_1: 0.8864 - val_loss: 1.9131 - val_accuracy: 0.4465 - val_precision_0: 0.7100 - val_recall_0: 0.5066 - val_F1_0: 0.5913 - val_precision_1: 0.1058 - val_recall_1: 0.2200 - val_F1_1: 0.1429
# Epoch 143/150
# 57/57 [==============================] - 7s 120ms/step - loss: 0.2252 - accuracy: 0.9059 - precision_0: 0.9189 - recall_0: 0.9213 - F1_0: 0.9201 - precision_1: 0.9077 - recall_1: 0.9051 - F1_1: 0.9063 - val_loss: 1.9241 - val_accuracy: 0.4214 - val_precision_0: 0.7371 - val_recall_0: 0.4164 - val_F1_0: 0.5322 - val_precision_1: 0.1667 - val_recall_1: 0.4400 - val_F1_1: 0.2418
# Epoch 144/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2089 - accuracy: 0.9187 - precision_0: 0.9324 - recall_0: 0.9260 - F1_0: 0.9291 - precision_1: 0.9154 - recall_1: 0.9231 - F1_1: 0.9192 - val_loss: 2.2972 - val_accuracy: 0.3249 - val_precision_0: 0.6455 - val_recall_0: 0.3236 - val_F1_0: 0.4311 - val_precision_1: 0.1146 - val_recall_1: 0.3300 - val_F1_1: 0.1701
# Epoch 145/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2082 - accuracy: 0.9053 - precision_0: 0.9291 - recall_0: 0.9331 - F1_0: 0.9311 - precision_1: 0.9256 - recall_1: 0.9213 - F1_1: 0.9234 - val_loss: 1.8605 - val_accuracy: 0.4465 - val_precision_0: 0.7251 - val_recall_0: 0.4828 - val_F1_0: 0.5796 - val_precision_1: 0.1372 - val_recall_1: 0.3100 - val_F1_1: 0.1902
# Epoch 146/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.2089 - accuracy: 0.9154 - precision_0: 0.9254 - recall_0: 0.9173 - F1_0: 0.9213 - precision_1: 0.9082 - recall_1: 0.9162 - F1_1: 0.9121 - val_loss: 2.0111 - val_accuracy: 0.3899 - val_precision_0: 0.6903 - val_recall_0: 0.4138 - val_F1_0: 0.5174 - val_precision_1: 0.1195 - val_recall_1: 0.3000 - val_F1_1: 0.1709
# Epoch 147/150
# 57/57 [==============================] - 6s 111ms/step - loss: 0.2125 - accuracy: 0.9048 - precision_0: 0.9053 - recall_0: 0.9155 - F1_0: 0.9103 - precision_1: 0.9012 - recall_1: 0.8898 - F1_1: 0.8954 - val_loss: 1.9225 - val_accuracy: 0.4088 - val_precision_0: 0.6908 - val_recall_0: 0.4562 - val_F1_0: 0.5495 - val_precision_1: 0.1009 - val_recall_1: 0.2300 - val_F1_1: 0.1402
# Epoch 148/150
# 57/57 [==============================] - 6s 110ms/step - loss: 0.2159 - accuracy: 0.9048 - precision_0: 0.9060 - recall_0: 0.9210 - F1_0: 0.9134 - precision_1: 0.9049 - recall_1: 0.8869 - F1_1: 0.8957 - val_loss: 2.0346 - val_accuracy: 0.4088 - val_precision_0: 0.6955 - val_recall_0: 0.4483 - val_F1_0: 0.5452 - val_precision_1: 0.1111 - val_recall_1: 0.2600 - val_F1_1: 0.1557
# Epoch 149/150
# 57/57 [==============================] - 7s 122ms/step - loss: 0.1898 - accuracy: 0.9148 - precision_0: 0.9078 - recall_0: 0.9263 - F1_0: 0.9168 - precision_1: 0.9132 - recall_1: 0.8917 - F1_1: 0.9021 - val_loss: 2.2974 - val_accuracy: 0.3878 - val_precision_0: 0.7114 - val_recall_0: 0.3793 - val_F1_0: 0.4948 - val_precision_1: 0.1522 - val_recall_1: 0.4200 - val_F1_1: 0.2234
# Epoch 150/150
# 57/57 [==============================] - 7s 121ms/step - loss: 0.1847 - accuracy: 0.9209 - precision_0: 0.9356 - recall_0: 0.9336 - F1_0: 0.9345 - precision_1: 0.9253 - recall_1: 0.9271 - F1_1: 0.9261 - val_loss: 2.0921 - val_accuracy: 0.5262 - val_precision_0: 0.7508 - val_recall_0: 0.5995 - val_F1_0: 0.6667 - val_precision_1: 0.1420 - val_recall_1: 0.2500 - val_F1_1: 0.1812

# %% [markdown]
# # results

# %% [markdown]
# ## loading test data

# %%
import glob
group1 = glob.glob('/A_LUAD/project/final_project/data/temp/two_test/group1/*.png')
group2 = glob.glob('/A_LUAD/project/final_project/data/temp/two_test/group2/*.png')

data = []
labels = []

for i in group1:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (300,300))
    image=np.array(image)
    data.append(image)
    labels.append(0)
for i in group2:   
    image=tf.keras.preprocessing.image.load_img(i, color_mode='rgb', 
    target_size= (300,300))
    image=np.array(image)
    data.append(image)
    labels.append(1)

x_test = np.array(data)
y_test = np.array(labels)

# %% [markdown]
# ## save eva results

# %%
name
# Out:
# '2-class-downsample1674160776'

# %%
######### evaluate model
testname = name + '_test'
results = model.evaluate(x_test, y_test)
# Out:
# 32/32 [==============================] - 2s 45ms/step - loss: 1.9574 - accuracy: 0.6076 - precision_0: 0.7907 - recall_0: 0.5725 - F1_0: 0.6529 - precision_1: 0.2048 - recall_1: 0.2168 - F1_1: 0.2104

# %%
test_path = '/A_LUAD/project/final_project/test_results'
## not sure
# test_name = name + '_pred.pickle'
# with open(os.path.join(test_path,test_name), 'wb') as file_pi:
#     pickle.dump(y_pred_lbls, file_pi)

######### visualization
y_pred=model.predict(x_test)
y_pred_lbls=np.argmax(y_pred,-1)

lbls=dict(map(lambda x: x.split('\t'),"""0 	<700 days
1 	>700 dayss""".split('\n')))
lbls={int(k):v for k,v in lbls.items()}

cm=ConfusionMatrixMetric(num_classes)
_=cm.update_state(y_test,y_pred)
fig, ax = plt.subplots(figsize=(6,4))
cm_matrix = cm.total_cm.numpy().astype(np.int32)
ax.matshow(cm_matrix, cmap=plt.cm.Blues)

for i in range(num_classes):
    for j in range(num_classes):
        c = cm_matrix[j,i]
        ax.text(i, j, str(c), va='center', ha='center')
plt.xticks(range(num_classes),['{} ({})'.format(lbls[i],'pred') for i in range(num_classes)])
plt.yticks(range(num_classes),['{} ({})'.format(lbls[i],'true') for i in range(num_classes)])
plt_name = name + '_loss'+str(round(results[0],2)) + '_acc'+str(round(results[1],2))+ '_p1_'+str(round(results[2],2))+ '_r1_'+str(round(results[3],2))+ '_f11_'+str(round(results[4],2))+ '_p2_'+str(round(results[5],2))+ '_r2_'+str(round(results[6],2))+ '_f12_'+str(round(results[7],2))+'_test.png'
plt.savefig(os.path.join(test_path, plt_name))
# plt.show()
