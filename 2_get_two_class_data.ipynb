# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import shutil
from PIL import Image
import glob
import shutil

# %% [markdown]
# # regroup data into two groups

# %% [markdown]
# ## regroup train data (same as three groups classification data)

# %%
all_data = pd.read_csv('/A_LUAD/project/final_project/data/temp/train_images.csv')

# make groups
listBins = [0, 700,1000000]
listLabels = ['1','2']
all_data['group'] = pd.cut(all_data['survival_days'], bins=listBins, labels=listLabels, include_lowest=True)
all_data.to_csv('/A_LUAD/project/final_project/data/temp/two_train_images.csv', index=False)

# %% [markdown]
# ## regroup val data (same as three groups classification data)

# %%
all_data = pd.read_csv('/A_LUAD/project/final_project/data/temp/val_images.csv')

# make groups
listBins = [0, 700,1000000]
listLabels = ['1','2']
all_data['group'] = pd.cut(all_data['survival_days'], bins=listBins, labels=listLabels, include_lowest=True)
all_data.to_csv('/A_LUAD/project/final_project/data/temp/two_val_images.csv', index=False)

# %% [markdown]
# ## regroup test data (same as three groups classification data)

# %%
all_data = pd.read_csv('/A_LUAD/project/final_project/data/temp/test_images.csv')

# make groups
listBins = [0, 700,1000000]
listLabels = ['1','2']
all_data['group'] = pd.cut(all_data['survival_days'], bins=listBins, labels=listLabels, include_lowest=True)
all_data.to_csv('/A_LUAD/project/final_project/data/temp/two_test_images.csv', index=False)

# %% [markdown]
# # split images to directory

# %%
# read csv files, get all information
image_paths = glob.glob("D:/A_LUAD/project/final_project/data/raw_data/*.png")
print("Total Observations:\t", len(image_paths))
# Out:
# Total Observations:	 4726

# %% [markdown]
# ## get train dir

# %%
data = pd.read_csv('/A_LUAD/project/final_project/data/temp/two_train_images.csv')
all_images_path = ['D:/A_LUAD/project/final_project/data/raw_data/{}.png'.format(i) for i in data['image_id'].values]

# %%
gb = data.groupby('group')
# group1 = grouped.getgroup('1')
group1 = gb[['image_id','group']].get_group(1)['image_id'].tolist()
group2 = gb[['image_id','group']].get_group(2)['image_id'].tolist()
groups = []
groups.append(group1)
groups.append(group2)
print(len(groups),len(groups[0]),len(groups[1]))
# Out:
# 2 1899 1176

# %%
new_root_path = '/A_LUAD/project/final_project/data/temp/two_train'
old_root_path = 'D:/A_LUAD/project/data/processed_images'

for i, group in enumerate(groups):
  group_name = 'group'+str(i+1)
  group_path = os.path.join(new_root_path,group_name)
  print(group_name)
  n = 0
  if not os.path.exists(group_path):
    os.makedirs(group_path)
  for image_id in group:
    image_name = image_id+'.png'
    image_old_path=os.path.join(old_root_path,image_name)
    image_new_path=os.path.join(group_path,image_name)
    shutil.copy(image_old_path,image_new_path)
# Out:
# group1
# group2

# %% [markdown]
# ## get val dir

# %%
data = pd.read_csv('/A_LUAD/project/final_project/data/temp/two_val_images.csv')
all_images_path = ['D:/A_LUAD/project/final_project/data/raw_data/{}.png'.format(i) for i in data['image_id'].values]

# %%
gb = data.groupby('group')
# group1 = grouped.getgroup('1')
group1 = gb[['image_id','group']].get_group(1)['image_id'].tolist()
group2 = gb[['image_id','group']].get_group(2)['image_id'].tolist()
groups = []
groups.append(group1)
groups.append(group2)
print(len(groups),len(groups[0]),len(groups[1]))
# Out:
# 2 552 100

# %%
new_root_path = '/A_LUAD/project/final_project/data/temp/two_val'
old_root_path = 'D:/A_LUAD/project/data/processed_images'

for i, group in enumerate(groups):
  group_name = 'group'+str(i+1)
  group_path = os.path.join(new_root_path,group_name)
  print(group_name)
  n = 0
  if not os.path.exists(group_path):
    os.makedirs(group_path)
  for image_id in group:
    image_name = image_id+'.png'
    image_old_path=os.path.join(old_root_path,image_name)
    image_new_path=os.path.join(group_path,image_name)
    shutil.copy(image_old_path,image_new_path)
# Out:
# group1
# group2

# %% [markdown]
# ## get test dir

# %%
data = pd.read_csv('/A_LUAD/project/final_project/data/temp/two_test_images.csv')
all_images_path = ['D:/A_LUAD/project/final_project/data/raw_data/{}.png'.format(i) for i in data['image_id'].values]

# %%
gb = data.groupby('group')
# group1 = grouped.getgroup('1')
group1 = gb[['image_id','group']].get_group(1)['image_id'].tolist()
group2 = gb[['image_id','group']].get_group(2)['image_id'].tolist()
groups = []
groups.append(group1)
groups.append(group2)
print(len(groups),len(groups[0]),len(groups[1]))
# Out:
# 2 452 547

# %%
new_root_path = '/A_LUAD/project/final_project/data/temp/two_test'
old_root_path = 'D:/A_LUAD/project/data/processed_images'

for i, group in enumerate(groups):
  group_name = 'group'+str(i+1)
  group_path = os.path.join(new_root_path,group_name)
  print(group_name)
  n = 0
  if not os.path.exists(group_path):
    os.makedirs(group_path)
  for image_id in group:
    image_name = image_id+'.png'
    image_old_path=os.path.join(old_root_path,image_name)
    image_new_path=os.path.join(group_path,image_name)
    shutil.copy(image_old_path,image_new_path)
# Out:
# group1
# group2
